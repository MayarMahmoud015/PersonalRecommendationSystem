# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: scikit-surprise in /opt/conda/lib/python3.10/site-packages (1.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.10/site-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-surprise) (1.14.1)

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import joblib
# sklearn - preprocessing
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler , OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# sklearn - metrics
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import Reader ,SVD ,accuracy 
from surprise.model_selection import cross_validate, train_test_split

import mlflow

# %% [markdown]
# # Data Preprocessing

# %%
import utils

# Load the dataset
df = utils.load_data('data/amazon_fine_food_reviews.csv')

# Clean the data by removing NaN values
df = utils.clean_data(df)

# Remove specific columns from the DataFrame
columns_to_remove = ['ProfileName','Id','HelpfulnessNumerator','HelpfulnessDenominator','Time','Summary','Text'] 
df = utils.remove_columns(df, columns_to_remove)

# Remove duplicate rows
df_no_duplicates = utils.remove_duplicates(df)
print(df.shape)
print(df_no_duplicates.shape)
df = df_no_duplicates.copy()

# %%
df.head()
# Out:
#     ProductId          UserId  Score
# 0  B001E4KFG0  A3SGXH7AUHU8GW      5
# 1  B00813GRG4  A1D87F6ZCVE5NK      1
# 2  B000LQOCH0   ABXLMWJIXXAIN      4
# 3  B000UA0QIQ  A395BORC6FGVXV      2
# 4  B006K2ZZ7K  A1UQRSCLF8GW1T      5

# %%
df.isna().sum()
# Out:
# ProductId    0
# UserId       0
# Score        0
# dtype: int64

# %%
df.hist(bins=160, figsize=(30, 15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Count the number of reviews for each user
review_counts = df['UserId'].value_counts().reset_index()

review_counts.head(20)
# Out:
#             UserId  count
# 0   A3OXHLG6DIBRW8    422
# 1    AY12DBB0U420B    389
# 2   A1YUL9PCJR3JTY    350
# 3   A281NPSIMI1C2R    322
# 4   A1Z54EM24Y40LL    251
# 5   A2MUGFV2TDQ47K    201
# 6    AQQLWCMRNDFGI    167
# 7    AZV26LP92E6WU    167
# 8    AY1EF0GOH80EK    157
# 9   A1UQBFCERIP7VJ    157
# 10  A2SZLNSI5KOQJT    155
# 11  A2FRFAQCWZJT3Q    154
# 12  A1WX42M589VAMQ    151
# 13  A3D6OI36USYOU1    150
# 14   AKMEY1BSHSDG7    149
# 15  A3HPCRD9RX351S    149
# 16  A2Y8IDC1FKGNJC    149
# 17  A2PNOU7NXB1JE4    143
# 18  A1IU7S4HCK1XK0    140
# 19   AKZKG2Z7CNV27    134

# %%
''''
We will use the users with a minimum number of reviews = 10 and ignore the rest.
Make a mapping to keep the relation between the userid column and other columns unchanged.
Use the users with min_reviews number or more and make the other with id NaN.
Drop the rows which have NaN values in userid column.
'''
min_reviews= 10

mapping = review_counts[review_counts['count'] >= min_reviews].set_index('UserId')['count'].to_dict()
df_new = df.copy()
#create a set of UserIds with counts >= min_reviews
valid_user_ids = set(review_counts[review_counts['count'] >= min_reviews]['UserId'])

#update UserId in the new df
df_new['UserId'] = df_new['UserId'].where(df_new['UserId'].isin(valid_user_ids), np.nan)

df_new.head(20)
# Out:
#      ProductId          UserId  Score
# 0   B001E4KFG0             NaN      5
# 1   B00813GRG4             NaN      1
# 2   B000LQOCH0             NaN      4
# 3   B000UA0QIQ             NaN      2
# 4   B006K2ZZ7K             NaN      5
# 5   B006K2ZZ7K             NaN      4
# 6   B006K2ZZ7K             NaN      5
# 7   B006K2ZZ7K             NaN      5
# 8   B000E7L2R4             NaN      5
# 9   B00171APVA             NaN      5
# 10  B0001PB9FE             NaN      5
# 11  B0009XLVG0  A2725IB4YY9JEB      5
# 12  B0009XLVG0             NaN      1
# 13  B001GVISJM  A18ECVX2RJ7HUE      4
# 14  B001GVISJM  A2MUGFV2TDQ47K      5
# 15  B001GVISJM             NaN      5
# 16  B001GVISJM             NaN      2
# 17  B001GVISJM             NaN      5
# 18  B001GVISJM  A2A9X58G2GTBLP      5
# 19  B001GVISJM             NaN      5

# %%
#now the new df have the user id with the highest number of reviews
#The rest ids become with value NaN, we will drop then
df_new['UserId'].isna().sum()
# Out:
# 427722

# %%
df_new =df_new.dropna(subset=['UserId'])
df_new.isna().sum()
# Out:
# ProductId    0
# UserId       0
# Score        0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 134908 entries, 11 to 568447
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ProductId  134908 non-null  object
#  1   UserId     134908 non-null  object
#  2   Score      134908 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 4.1+ MB

# %%
unique_values = df_new['ProductId'].unique()
print(f"Number of unique values in 'ProductId': {len(unique_values)}")
# Out:
# Number of unique values in 'ProductId': 27282

# %%
num_cols = ['Score']
categ_cols = []
ready_cols = list(set(df_new.columns.tolist()) - set(num_cols) - set(categ_cols))

print('Numerical Cols \t', num_cols)
print()
print('Categorical Cols \t', categ_cols)
print()
print('Ready Cols \t', ready_cols)
# Out:
# Numerical Cols 	 ['Score']
#
# Categorical Cols 	 []
#
# Ready Cols 	 ['ProductId', 'UserId']

# %% [markdown]
# # **We will try three approaches:**
#
# >**1- User-user collaborative based filtering**
#
# >**2- Item-item collaborative based filtering**
#
# >**3- Singular value decomposition (SVD)**
#
# **User-user collaborative based filtering**
# This method captures the underlying pattern of interests of like-minded users and uses the choices and preferences of similar users to suggest new items.
#
# In order to make a new recommendation to a user, the user-user method roughly tries to identify users with the most similar “interactions profile” (nearest neighbours) in order to suggest movies that are the most popular among these neighbours (and that are “new” to our user). This method is said to be “user-centred” as it represents users based on their interactions with items and evaluates distances between users.

# %%
# Define a Reader object to specify the rating scale
reader = Reader(line_format='user item rating timestamp', sep='\t', rating_scale=(1, 5))

# Load the data into a Surprise dataset
##notice that we use new df which have number of ratings more than min_reviews for each user
data = Dataset.load_from_df(df_new[['UserId', 'ProductId', 'Score']], reader)

# Compute similarities between users using cosine distance
sim_options = {"name": "cosine",
               "user_based": True}  

# Evaluate the model 
k = 30  #desired number of neighbors
user = KNNWithMeans(k=k, sim_options=sim_options)
cv = cross_validate(user, data, cv=5, measures=['RMSE', 'MAE'], verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9257  0.9328  0.9376  0.9407  0.9325  0.9339  0.0051
# MAE (testset)     0.6079  0.6113  0.6172  0.6152  0.6156  0.6134  0.0034
# Fit time          4.02    3.88    3.79    3.84    3.83    3.87    0.08
# Test time         3.15    3.16    3.32    3.29    3.27    3.24    0.07

# %% [markdown]
# **Item-item collaborative based filtering**
# To tackle the issues with user-based collaborative based techniques, item-based collaborative techniques analyze the user-item matrix and identify relationships between different items (Sarwar et al.,2001). The item-based recommendation system then makes recommendations based on the discovered linear relationships (similarities) amongst the items. This method is more stable compared to user based collaborative filtering because the average item has a lot more ratings than the average user. So an individual rating doesn’t impact as much.
#
# The idea of item-item method is to find movies similar to the ones the user already “positively” interacted with. Two items are considered to be similar if most of the users that have interacted with both of them did it in a similar way. This method is said to be “item-centred” as it represents items based on interactions users had with them and evaluates distances between those items.

# %%
# Compute similarities between items using cosine distance
sim_options = {"name": "pearson",
               "user_based": False}  

# Fit the KNNwithmeans algorithm to the training set
k= 10
item_based = KNNWithMeans(k=k, sim_options=sim_options)

# Evaluate the model 
cv = cross_validate(item_based, data, cv=5, measures=['RMSE','MAE'], verbose=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8927  0.9059  0.8932  0.9064  0.9018  0.9000  0.0060
# MAE (testset)     0.5034  0.5098  0.5038  0.5123  0.5069  0.5072  0.0034
# Fit time          33.73   32.25   31.86   31.56   31.79   32.24   0.78
# Test time         1.52    1.35    1.35    1.39    1.52    1.42    0.08

# %% [markdown]
# **Singular value decomposition (SVD)**
#
# Unlike Memory-Based Approaches, Model-Based procedures facilitate machine learning techniques such as Singular Value Decomposition (SVD) and Matrix Factorization models to predict the end user's rating on unrated items.
#
# We will be using SVD to build our recommender engine. We utilize the results of singular value decomposition (SVD) to fill the vacant ratings and then use the item based method to produce the prediction of unrated items.
#
# Formally, SVD is decomposition of a matrix R which is the utility matrix with m equal to the number of users and m number exposed items (movies) into the product of three matrices:
#
# U is a left singular orthogonal matrix, representing the relationship between users and latent factors (Hopcroft & Kannan, 2012)
#
# Σ is a diagonal matrix (with positive real values) describing the strength of each latent factor
#
# V(transpose) is a right singular orthogonal matrix, indicating the similarity between items and latent factors.

# %%
svd = SVD(random_state=0, lr_all= 0.1)
cv = cross_validate(svd, data, cv=5, measures=['RMSE','MAE'], verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8025  0.7922  0.7886  0.8079  0.7978  0.7978  0.0069
# MAE (testset)     0.4837  0.4744  0.4701  0.4826  0.4754  0.4772  0.0052
# Fit time          2.27    2.28    2.29    2.34    2.31    2.30    0.03
# Test time         0.47    0.28    0.27    0.27    0.47    0.35    0.10

# %% [markdown]
# **Using SVD gives us a RMSE score of 0.798   which is promising and the best of the 3 we've tested. We will go ahead and train this model using the entire dataset.**

# %% [markdown]
# # **Submission using SVD**

# %%
# Define a Reader object to specify the rating scale
reader = Reader(line_format='user item rating timestamp', sep='\t', rating_scale=(1, 5))

# Load the data into a Surprise dataset
##notice that we use new df which have number of ratings more than min_reviews for each user
data = Dataset.load_from_df(df_new[['UserId', 'ProductId', 'Score']], reader)

# Split the data into training and test sets
trainset, testset = train_test_split(data, test_size=0.2)

# %%
# Instantiate the SVD model
svd = SVD(random_state=0, lr_all= 0.1)

svd.fit(trainset)

# %%
# Predict ratings for the test set
predictions = svd.test(testset)

# Compute and print RMSE and MAE
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 0.7955
# MAE:  0.4748

# %%
testset
# Out:
# [('ARWRBORADGA3G', 'B005K4Q1VI', 5.0),
#  ('A35LT14WG5BX0T', 'B004OVATO8', 4.0),
#  ('A318D41ZQ9OPNA', 'B001E18K8S', 3.0),
#  ('AX1Z5RQ1LWMM2', 'B000OIT8T2', 5.0),
#  ('A26NFIQ7KWI8Y7', 'B007OXJLM4', 4.0),
#  ('A3F2VVIQIY6U64', 'B005BPVB84', 4.0),
#  ('A9GQR7CMQERSS', 'B00141SO7A', 1.0),
#  ('A15JB2HEZ6RKGW', 'B006MONQMC', 5.0),
#  ('A2WYP6MZRK4G4A', 'B0029NIFXK', 5.0),
#  ('A19ZK2D5664XKL', 'B000EQYQBO', 5.0),
#  ('AWLK6NSSV0YNA', 'B004728MI4', 5.0),
#  ('AS0SPE5TEM74Z', 'B004JLGDJI', 5.0),
#  ('AZA55FJD7CCZN', 'B005VOONKI', 4.0),
#  ('A3ACCH1UM0OKVU', 'B000WVYB8Y', 5.0),
#  ('ACFPHOYVB71V4', 'B000G6MBUA', 5.0),
#  ('ASPZBFGF4AS8H', 'B000MIDRNW', 5.0),
#  ('A3FG0FQHNV2UP2', 'B007RTR8UM', 2.0),
#  ('AI8EMB0HUC6Z5', 'B004BKLHOS', 5.0),
#  ('A1MLQY4WBCWD31', 'B001SIRU42', 3.0),
#  ('ADS99W8WMEXZ2', 'B005VOOL00', 4.0),
#  ('A20J0NBT6FWXXM', 'B0041CIR62', 5.0),
#  ('A37AO20OXS51QA', 'B000T3KTJA', 2.0),
#  ('AUOA7P6T8JXSE', 'B0012BUR8Q', 5.0),
#  ('AO09RWV40IX78', 'B000AY9U20', 5.0),
#  ('A39ZG9XWPS3JU7', 'B005HB4HHO', 5.0),
#  ('A15LK8DSFQZZ52', 'B004YV80OE', 3.0),
#  ('A8PZHR49KMCRP', 'B002HFWNKG', 5.0),
#  ('A3NCTCNAUYCH6H', 'B001EO5T52', 4.0),
#  ('AYOMAHLWRQHUG', 'B001EO6BFE', 5.0),
#  ('A9LWNO452P7UU', 'B000CONM86', 5.0),
#  ('A2VH0UT5EQFB6P', 'B002LANN56', 4.0),
#  ('A70T8C7VM2ZUW', 'B00073JVFU', 5.0),
#  ('A1UMSB7LAW0RIR', 'B002T0NWKE', 5.0),
#  ('A1F7SX3GNVBNE3', 'B005VTXQKG', 2.0),
#  ('ABDBADU0RLIYN', 'B004IJHY4Y', 1.0),
#  ('A3MUSWDCTZINQZ', 'B005VOOQHS', 5.0),
#  ('A3882RXW8MO4J4', 'B0061IUIDY', 4.0),
#  ('A2F2MZW8EOGH5J', 'B001TM2A24', 5.0),
#  ('A1COSZMOI965TQ', 'B000VTTAMY', 1.0),
#  ('A2HJPG1L877M73', 'B003CK0XC0', 5.0),
#  ('A3JZJQHY3159IQ', 'B003VIWN1W', 4.0),
#  ('A2MUGFV2TDQ47K', 'B0025UNVA4', 5.0),
#  ('AL63HUU233ID2', 'B001SITXH4', 1.0),
#  ('A26M5O53PHZTKN', 'B000JSLYSU', 5.0),
#  ('A19XBW5WUDH1Z', 'B002ZJ3C18', 1.0),
#  ('A7EK88GF8N40F', 'B004E4EBMG', 3.0),
#  ('A1QR76SYGTXJN5', 'B008RWUHA6', 4.0),
#  ('APPJNVNF4BFLB', 'B000UJW0W2', 2.0),
#  ('AL7R5LO0AUGKQ', 'B000LKV7QA', 5.0),
#  ('A5CG559ETQAWN', 'B000EVKHQM', 5.0),
#  ('A18IZ3RTL9SD4V', 'B001RVFERK', 4.0),
#  ('A2FS9CYCWC6HLW', 'B0014DUG0Q', 4.0),
#  ('A37MH7ICH80QOX', 'B002RBOCZE', 4.0),
#  ('A4E39G95DZXBC', 'B001SIRU42', 3.0),
#  ('A1G34E8KZ8VQJO', 'B000LKXQ6O', 5.0),
#  ('A3I7J622UUG6LB', 'B000EGZ2L2', 5.0),
#  ('A385E4RHJS3T57', 'B0034EDM2W', 3.0),
#  ('A1YUL9PCJR3JTY', 'B000JVCE5Y', 3.0),
#  ('AYGIIQGSHKZNI', 'B000YZTAS4', 5.0),
#  ('A1TNKFJBUL0ZAV', 'B000WFM9QQ', 5.0),
#  ('A31MZR41SM9JU5', 'B002DHTWNO', 1.0),
#  ('A1IZJVLNMFACS6', 'B007RTR8T8', 4.0),
#  ('A2JMKYNXTG6MVN', 'B000EVG8J2', 5.0),
#  ('A21U4DR8M6I9QN', 'B000WN47JU', 5.0),
#  ('AENJBZSAD6ARY', 'B000E1FY3I', 5.0),
#  ('A3CIVGG3HNS1GM', 'B001LG940E', 5.0),
#  ('AWLK6NSSV0YNA', 'B000HGC988', 5.0),
#  ('A376OJHLE6SU9Q', 'B002IEZJMA', 2.0),
#  ('A1V2KJE03N4AE1', 'B000F4990I', 4.0),
#  ('A2O421DTA8J0RW', 'B001AYDDCC', 4.0),
#  ('A1QLPXFD05AMOU', 'B002YLG6I8', 5.0),
#  ('A20A9P8EJ5BREG', 'B008EG5ADY', 4.0),
#  ('ADPCK648WY0LZ', 'B000FVDWU4', 1.0),
#  ('A2WLS1TTUUGJYU', 'B001ELL260', 5.0),
#  ('A2EDWI5EGP4V9N', '7310172101', 4.0),
#  ('A1SZTVG2IXWY2R', 'B000FPKX3O', 4.0),
#  ('A2O421DTA8J0RW', 'B006BXUYN8', 5.0),
#  ('A3L9ZT7SRJYLVH', 'B000SV5DKS', 5.0),
#  ('A2IBUE2WR08IBH', 'B000OH57ZW', 5.0),
#  ('A1LTDEUQUFK1WC', 'B007PA33QG', 3.0),
#  ('A6VFX3VLU7NO6', 'B0087GG8OG', 5.0),
#  ('A1421EDED1JI4I', 'B00166D8TW', 5.0),
#  ('A27DYAY3FUWIZ8', 'B000FFQ1ZI', 5.0),
#  ('A33PVCHCQ2BTN0', 'B00503DP0O', 5.0),
#  ('A3LGT6UZL99IW1', 'B004YGQPAK', 4.0),
#  ('A3D6OI36USYOU1', 'B00023323W', 5.0),
#  ('A3UDKADSH2NSZU', 'B0019QT66I', 5.0),
#  ('A33U8304RD0F6B', 'B0038C6X8A', 5.0),
#  ('A19SXBQWY5Y4YW', 'B0030VJ8PE', 5.0),
#  ('A2NML53YCHS80S', 'B005QRPHPU', 5.0),
#  ('A370FTMPRF0AIK', 'B000Q7535Y', 5.0),
#  ('A3W1ZA5JQVT33G', 'B000EDGBA6', 5.0),
#  ('ARK11CB6Q8LQN', 'B00438XVGU', 5.0),
#  ('A3MDETK0D5UAIN', 'B007RTR9DS', 2.0),
#  ('ACG6O0II5IZE1', 'B001EO5QPA', 5.0),
#  ('ANR7N0TPK3RB9', 'B001D0DMME', 5.0),
#  ('A3N4CUW4UYC9I3', 'B0090X8IPM', 4.0),
#  ('A2W3ABLWMJ84NS', 'B000LKVL16', 1.0),
#  ('AIEEK7AHXKZCC', 'B000NMJWZO', 5.0),
#  ('A2SSV6KM3W1VFD', 'B001BCVY9W', 5.0),
#  ('A3JLECMNWC4LDY', 'B000CQID6U', 1.0),
#  ('A21SL94J53BDS9', 'B006MONQMC', 3.0),
#  ('A1BTHZO04GVCS6', 'B001BM8SS2', 5.0),
#  ('A3QZ6JT0R1OWEC', 'B000IBILV6', 1.0),
#  ('A2Y8IDC1FKGNJC', 'B005BPVA08', 3.0),
#  ('A2GP6XJ1V3MM3L', 'B001216DFM', 5.0),
#  ('A35R32TA60XD57', 'B001BCUB7S', 5.0),
#  ('A3C6SSXXFE1J4L', 'B001SITWC0', 5.0),
#  ('A3F2926FPOBNL', 'B008GRONV6', 5.0),
#  ('A5YO6D3KN7GDR', 'B001FYUVG8', 5.0),
#  ('A3F45B9WS0JO5F', 'B000WFUL3E', 5.0),
#  ('A1XG5WYLFMRRX1', 'B008O3G2K2', 1.0),
#  ('A3EP6YVAYS9YM3', 'B004U49QU2', 3.0),
#  ('A151X4F0YRN2OA', 'B003M61F0I', 2.0),
#  ('A35TIC6B8MVKWG', 'B00141NFHO', 5.0),
#  ('A2NI95Y8UNE85D', 'B003KV7V1C', 5.0),
#  ('A1X1SCXSV7SE10', 'B000CQIDHE', 1.0),
#  ('ANS906E4EOXB3', 'B000CQE3NM', 5.0),
#  ('A101P2KHWCU0G6', 'B000084DWM', 1.0),
#  ('A2TTHN1UMO82VY', 'B001AHL6CI', 5.0),
#  ('AUGXZ6WTKYEKO', 'B000HZH8NA', 5.0),
#  ('A2K3J2X8KDY47N', 'B000MICPSA', 5.0),
#  ('AWDU2JPGHV6ST', 'B000Q6XR0S', 5.0),
#  ('AOK57RN8TE13K', 'B002C1CWLA', 5.0),
#  ('A2N19WG3ZA01N6', 'B0012V1G0Y', 5.0),
#  ('AQLL2R1PPR46X', 'B001AHFVHO', 5.0),
#  ('A20MMCAHGALRAX', 'B0009F3QLQ', 5.0),
#  ('A3B2IP2Q0CUBI6', 'B003MA8P02', 1.0),
#  ('A2VHX2LUXMLS18', 'B004JLGEDS', 5.0),
#  ('A25IN8E5N6HJ16', 'B000EMM9WG', 2.0),
#  ('A3PJZ8TU8FDQ1K', 'B004728MI4', 5.0),
#  ('AIOYMXZNIE4ZN', 'B001EO5U8I', 5.0),
#  ('A2DDALFVSQTE0J', 'B00020HHHC', 5.0),
#  ('A891P0KYK4HJV', 'B000SE6JCG', 5.0),
#  ('A25V7KAUQZ1W1W', 'B001EDERN8', 5.0),
#  ('A26X7W5UM5QFT4', 'B000LKVEC2', 5.0),
#  ('A30HTE062DH3KC', 'B001ELL68Y', 5.0),
#  ('A3CWJ604OXQ4RX', 'B000CQBZV0', 5.0),
#  ('A2NV6EVUDPV0OP', 'B000FK7PP8', 5.0),
#  ('AR33KU52LIBF1', 'B000VXYV6K', 5.0),
#  ('A31BANT0XA7VDA', 'B000WVYB8Y', 5.0),
#  ('A3PJRR03ZAFWGR', 'B00020HHK4', 2.0),
#  ('A3Q9HY0LU7MN6E', 'B0083QJU5O', 5.0),
#  ('A1PN3SJAP1TBTU', 'B004TZGBDM', 5.0),
#  ('A3KWRPM3DWXNXW', 'B000FVDWU4', 5.0),
#  ('A3IUW081KXD3PE', 'B000PGA8WY', 5.0),
#  ('A29JUMRL1US6YP', 'B000WFKWDI', 5.0),
#  ('A3I8RIBAXJ31HK', 'B007HP6IDE', 5.0),
#  ('A1S3DCJ9T7GAK', 'B003EI9LSC', 4.0),
#  ('A3LVWAIK5YN22G', 'B002OFUC8O', 5.0),
#  ('AJ1CE24O54TFM', 'B000255OIG', 5.0),
#  ('A1SO1PGDNVMLXC', 'B001I4CA46', 3.0),
#  ('AYNAH993VDECT', 'B004NSKWMQ', 5.0),
#  ('A1BE8V5S9IYE9E', 'B000F0FZAU', 4.0),
#  ('A2T9EHCUD7CNEB', 'B005VOONLW', 4.0),
#  ('A1YUL9PCJR3JTY', 'B000CQID2Y', 3.0),
#  ('AIPBPZT9QR9CC', 'B004SKZWBK', 5.0),
#  ('A2ZOVHKYDH4UOJ', 'B001D0IZ4O', 4.0),
#  ('A3OC93X866Z8TB', 'B0029O10P4', 5.0),
#  ('A1ZKGSDVP057L9', 'B002NHYQAS', 3.0),
#  ('A2M069CN0QEW5N', 'B002TMV3GC', 1.0),
#  ('A22MANL4US4RMY', 'B000KOQJ4C', 5.0),
#  ('AGLKENC7EJDYW', 'B0045IO37Y', 5.0),
#  ('AJ9AE2BVND0GS', 'B000FK8VHE', 5.0),
#  ('A1ONT5BHMPV111', 'B001SAUMQ8', 5.0),
#  ('A1XQMQMF07QZQS', 'B000RHSX9G', 5.0),
#  ('AA7S590A4K4Z2', 'B000DZH19U', 5.0),
#  ('A18EKQMJ0TK6K5', 'B001D0DMME', 5.0),
#  ('A3VKBFC5K2INR4', 'B000N33NSU', 5.0),
#  ('ATCT22YM2HUQ8', 'B0014AUJII', 4.0),
#  ('A1CIU572HUUE5A', 'B000LKU3DI', 4.0),
#  ('A1EA3QWLRO24X8', 'B0016FRI8A', 5.0),
#  ('AD2QRU9ZXBQZ1', 'B000084F1I', 5.0),
#  ('AORGKBNQZ83O8', 'B00503DP0O', 4.0),
#  ('A2Q1ELWEHTTTF5', 'B000HDONP8', 5.0),
#  ('A2FDEV3OLZNJ19', 'B0012BUR8Q', 5.0),
#  ('A2YSFKX18XTHED', 'B001BDDTB2', 5.0),
#  ('A22BGI38W7Q9X9', 'B0025UCGVE', 4.0),
#  ('A28GRFVAA4DU5P', 'B0019FGRJI', 4.0),
#  ('A1R1BFJCMWX0Y3', 'B00141NFHO', 5.0),
#  ('A32C3JZ8S2DKT0', 'B003SSWCJI', 4.0),
#  ('A37IHRVO8JWYF2', 'B005A1LJ04', 4.0),
#  ('AU0GRA7EJUH34', 'B000AY9UBQ', 3.0),
#  ('A3PJZ8TU8FDQ1K', 'B005BPVB9S', 5.0),
#  ('A2II54B3VA45LN', 'B000FMZO8G', 2.0),
#  ('A1LHOKYENR7HP2', 'B00356FSAS', 5.0),
#  ('A2ZKQC0XCIIAEM', 'B004E4CCSQ', 5.0),
#  ('A1IVVJE88QA7JN', 'B001EQ4QJK', 5.0),
#  ('A1UD16T8XBNNIE', 'B001TLY7A8', 2.0),
#  ('A2SJ8E8C032733', 'B00817GPWQ', 4.0),
#  ('AJRHMTSVM2D16', 'B00125ZCWI', 5.0),
#  ('AJQS35BZ2GMU4', 'B000CNB4LE', 5.0),
#  ('AX0ZTNX6KVJ40', 'B005A1LINC', 4.0),
#  ('AI8B17RJ6FGA0', 'B003MW7858', 5.0),
#  ('A1N655X9X7C6QY', 'B005VOONKI', 4.0),
#  ('A3P84TZX9X1B3X', 'B00164UZ4A', 3.0),
#  ('A1GCOURMTPXKWI', 'B00158U8DU', 5.0),
#  ('A6WME11TGFMEW', 'B000I1RHMU', 5.0),
#  ('A2GJ13F7WIYX2E', 'B000ETGBN2', 4.0),
#  ('A235UFZGCFN3J5', 'B0002I0GZO', 5.0),
#  ('A2SZLNSI5KOQJT', 'B0018CE7BC', 4.0),
#  ('A2EWE0GMBBUVMJ', 'B000FBQ54Y', 5.0),
#  ('A2L9G81KGUXOD7', 'B000W2GXKC', 5.0),
#  ('A2D1LPEUCTNT8X', 'B003VXFK44', 3.0),
#  ('A3DAS42VRO66SN', 'B000MXHQQ6', 5.0),
#  ('A3KJFAHSF48KH3', 'B003MZV3PG', 5.0),
#  ('AVKZ6PSXX72A7', 'B001EO671M', 5.0),
#  ('ASBLUZWS98EM2', 'B00283A8TA', 5.0),
#  ('AY46DEOJJYFTW', 'B0044CPA28', 5.0),
#  ('A2A5MBGYJUXTD0', 'B000F4F94S', 5.0),
#  ('AIZBSI36ZSV9E', 'B001EO5TGQ', 5.0),
#  ('A1A1BM6N28X9J0', 'B0041CIR62', 1.0),
#  ('A3B6TOEXSQVO24', 'B000LKVD5U', 5.0),
#  ('A3J0J4DXDMQTIN', 'B0039LVLS2', 2.0),
#  ('A3JKI7AWYSTILO', 'B0019O4Y8K', 5.0),
#  ('A3503I7GE6D70C', 'B002HFWNKG', 5.0),
#  ('A1DC1O4VX6AHPP', 'B002D4DY8G', 5.0),
#  ('ALDYWG0CPSYUF', 'B007TGO1U8', 5.0),
#  ('A27QWSAXIABQUP', 'B000F4DKAI', 5.0),
#  ('A19ZK2D5664XKL', 'B000EQX57K', 5.0),
#  ('AJQD2WWJYOYFQ', 'B0058AMY10', 4.0),
#  ('ATN4J5VS8Q0YM', 'B0045XE32E', 5.0),
#  ('A2N6TULZUWMW2Z', 'B001E8DHPW', 3.0),
#  ('AAUICTIUBVU7R', 'B0040Q0RDU', 5.0),
#  ('A336FE20YZZL3A', 'B004YV80OE', 5.0),
#  ('A11OTLEDSW8ZXD', 'B00207XKBW', 3.0),
#  ('A2TMS1YC8SNFV', 'B0014JUPTW', 4.0),
#  ('AOSV7VXZQ1EI2', 'B000EYRHL2', 4.0),
#  ('A33AQPJYH7UUXR', 'B000H7LVKY', 5.0),
#  ('A1GZVRXW89KZST', 'B003TC7WN4', 5.0),
#  ('A4JHEO7H330AF', 'B003GTR8IO', 1.0),
#  ('AVP3I6MPAICQG', 'B006HYLW32', 5.0),
#  ('A108XP24UESKSV', 'B007I7YZJK', 5.0),
#  ('A2U77Z3Z7DC9T9', 'B004VLVIR8', 5.0),
#  ('A1LHAXBM5GBJS2', 'B001LGGH40', 4.0),
#  ('A28CP4HAD8KLJT', 'B000CQC0BE', 4.0),
#  ('A1UP81S8OCJASL', 'B003NDA970', 5.0),
#  ('A3QO73FZ1J4DIT', 'B002RBOB9G', 5.0),
#  ('A2K4ZBXN90KTKJ', 'B000ETGBN2', 5.0),
#  ('AMW636ZQYB7MC', 'B00008CQVA', 2.0),
#  ('A45S6D1P309G9', 'B004FEJ968', 3.0),
#  ('AJWLSDYCSQNBL', 'B000G6MBUA', 1.0),
#  ('A1PU4RV8JOE94Y', 'B001FYZ0W8', 5.0),
#  ('A30VOG29YPU59V', 'B004FEN3GA', 4.0),
#  ('A3A3FL72P6QD2C', 'B003M5XJ6C', 5.0),
#  ('A33AQPJYH7UUXR', 'B0001CXUHW', 5.0),
#  ('A35VI0H5AFHOJ5', 'B001EQ5HCK', 5.0),
#  ('A1Z4LX3Q1YMF84', 'B000VK8HJ0', 2.0),
#  ('A3R5GTYQ50QVMD', 'B006BXV1H6', 3.0),
#  ('AQVB6GHDASQT4', 'B001PMDYZA', 1.0),
#  ('A2OUNVRPRWH0', 'B000VK8HJ0', 4.0),
#  ('ACYR6O588USK', 'B004KIWT7K', 5.0),
#  ('A3SQV1Q3LQH59Z', 'B001D0DMME', 4.0),
#  ('A3GRN6J64F2C3X', 'B002NHYQAS', 5.0),
#  ('A13HRSMJ5TOWEZ', 'B000CQC0BE', 5.0),
#  ('AUS545VE0P2J1', 'B008JKTH2A', 5.0),
#  ('A34YVCO8S3BMJX', 'B003ZTCINA', 1.0),
#  ('A3TSQVDK4TZ1VD', 'B001EO6190', 2.0),
#  ('A3J356L2ADK05Z', 'B004JRO1S2', 4.0),
#  ('A1RI7WJSWQW2CZ', 'B005YSYWCU', 5.0),
#  ('ATJN4KEHJBOC8', 'B000GFYRIA', 5.0),
#  ('A7UPJYPAH73NC', 'B001AHJ2D8', 4.0),
#  ('A3H7NPNDMGLOU4', 'B003GTR8IO', 3.0),
#  ('A3C2F0J9YACVB1', 'B000EVG8H4', 3.0),
#  ('A33DKGANHQJSXC', 'B002UQJ9PY', 5.0),
#  ('A3URG3C2QF17RR', 'B005GIF5UQ', 5.0),
#  ('A236V1U1P2K4OG', 'B002AN4TWK', 2.0),
#  ('A3FB7HNV5IY8J8', 'B000WVYB8Y', 5.0),
#  ('A215P85W653CZV', 'B006Q7YG2O', 4.0),
#  ('A1T61QP7QHYBRQ', 'B005B3HKPO', 5.0),
#  ('A3LDKPBIJTKCVD', 'B000GAO91K', 5.0),
#  ('A2DYW9Y2D8E43L', 'B00080LHJU', 5.0),
#  ('A1YFI21CFKYV5I', 'B0014ATRV8', 5.0),
#  ('A3KJ9ONYM913Z', 'B001GINOQC', 5.0),
#  ('AI0NMYA3LKXW1', 'B000CQC04Q', 5.0),
#  ('ACAIEIV03NBHY', 'B0044CR12A', 5.0),
#  ('A108AL4ECMBV9X', 'B007M83302', 5.0),
#  ('A379IB3EYAEL5', 'B006HYLW32', 5.0),
#  ('A3NUEGR0HSU0TH', 'B000AY9UBQ', 5.0),
#  ('A34DQINHT6NYJU', 'B002TMV34E', 4.0),
#  ('A2PNOU7NXB1JE4', 'B001PMDYXW', 3.0),
#  ('A88USYRFGDUTK', 'B001E18K8S', 5.0),
#  ('A3774UJAKO4FHI', 'B000FVBYCW', 5.0),
#  ('A2R95Z7PTF5ZRO', 'B001BM4NAE', 5.0),
#  ('A3EX36SNRYD5VL', 'B000FA38ZY', 4.0),
#  ('AY12DBB0U420B', 'B003IDF86C', 5.0),
#  ('A30V1I648K4IKD', 'B000WFU8O6', 4.0),
#  ('A1B3M9FMMDZSQZ', 'B003WK0D8O', 5.0),
#  ('AR5SY32T76DBM', 'B006MONQMC', 4.0),
#  ('A1VBDMNT6I8RE5', 'B004JRKEH4', 5.0),
#  ('AIKK0O36ZIWM0', 'B000OQ2DJQ', 4.0),
#  ('A135XHGMBR0OWF', 'B000FMZO8G', 5.0),
#  ('A2Y1DXML62KMOR', 'B004HOQE64', 5.0),
#  ('A2I069BL3ENRAM', 'B002L96X68', 5.0),
#  ('A3MNAQZ8DQQTAD', 'B003AK90N0', 4.0),
#  ('A3U5JCXIXTGSLN', 'B001LG945O', 1.0),
#  ('A1UKA7HUAQAMY', 'B0090X8IPM', 4.0),
#  ('A1OMXVXXP07F05', 'B004BKLHOS', 3.0),
#  ('A1WTP99BOA0PGA', 'B001PAOPPK', 5.0),
#  ('A2OWR2PL3DLWS4', 'B0039KERAM', 5.0),
#  ('ALJ1S9LOYB08X', 'B004HOTD6M', 5.0),
#  ('A3D8VSMH4EBRZ2', 'B000CQC04Q', 5.0),
#  ('A3436BWMMFP4VY', 'B001EQ55RW', 5.0),
#  ('A2QG4B0FCPOGW5', 'B000H5DADW', 5.0),
#  ('A2UW73HU9UMOTY', 'B000EZSFVW', 5.0),
#  ('A3KW8U52DHBD0E', 'B001BLXRPC', 1.0),
#  ('A15QRUAQB1QWVD', 'B000M0F58U', 5.0),
#  ('A1TR1R2QKWRSRA', 'B006MONQMC', 3.0),
#  ('A35MDIBPAX9X7U', 'B004ET9OLY', 5.0),
#  ('A27NTH2Y9DAR31', 'B008Z4VAPM', 5.0),
#  ('A2VTVPQVTZ8W1A', 'B0009VO58S', 5.0),
#  ('A2BOGWVZ40AKPO', 'B004P7T7ZS', 5.0),
#  ('A32B6A532454UD', 'B000H23Z1C', 5.0),
#  ('A1YUL9PCJR3JTY', 'B0017IAMU2', 5.0),
#  ('A18ZEMA7Y1HPMN', 'B0015R9BQG', 5.0),
#  ('A58N07M0ZCYMB', 'B0040K41MY', 4.0),
#  ('A2FBD3A4TBXMBG', 'B0014AUJII', 5.0),
#  ('A134S6TOUH24QV', 'B000WFKGR0', 5.0),
#  ('AOR52NN9OR1QK', 'B001EO5RRM', 1.0),
#  ('A2GEZJHBV92EVR', 'B0050W6JGW', 5.0),
#  ('ARK11CB6Q8LQN', 'B00451WLYI', 5.0),
#  ('AC0HPFQVBZVGY', 'B005VOOQHS', 5.0),
#  ('A14Y3S3R0KO9J9', 'B0049ZCF9G', 5.0),
#  ('A2UTZ7HH4UKDZW', 'B000TIZP5I', 5.0),
#  ('AIM47BCJFPC0T', 'B000LKVHZG', 4.0),
#  ('A1ILANU80CJWTX', 'B001E0TBA0', 5.0),
#  ('A2TF7DG89YTV8M', 'B001EQ4P2I', 5.0),
#  ('A3CQNW9IU1QE6L', 'B000FBQ54Y', 5.0),
#  ('A39KT4ATF5Q9UB', 'B004JWS0CA', 5.0),
#  ('A1XEHQJ0UHJ18E', 'B002QWHJOU', 5.0),
#  ('A3HPCRD9RX351S', 'B0007A0AQM', 5.0),
#  ('A3V1A3C9DTLPME', 'B003DGQBCO', 5.0),
#  ('A31J176KH7ZZEY', 'B003GADBDO', 5.0),
#  ('A1SVXJZ3386U2D', 'B004FEN3GA', 3.0),
#  ('A1BT6TL7UCIC5Y', 'B0002DJZX8', 3.0),
#  ('A2SZWFJX0783BF', 'B005GXFCYK', 2.0),
#  ('A3H8288VHL1607', 'B001AIQP8M', 4.0),
#  ('A2D1LPEUCTNT8X', 'B004FEN3GA', 5.0),
#  ('A2NOJMODF77E0J', 'B001D09KAM', 5.0),
#  ('AVFA1JB08RG8G', 'B000I1OLT2', 4.0),
#  ('A2AV1LZY0VBF8C', 'B001EQ596O', 4.0),
#  ('A3EU15A30PLO1A', 'B0009DY554', 5.0),
#  ('A2ETDX2PIFTCQD', 'B001GVIRKM', 5.0),
#  ('AL5VAC89VKZ97', 'B000FNEX8C', 4.0),
#  ('A1AG7F4Z1EOO5L', 'B006J4MAUE', 4.0),
#  ('A1PI8VBCXXSGC7', 'B0041NYV8E', 4.0),
#  ('A24N79JNVNFSBV', 'B000VK8AVK', 5.0),
#  ('A39ONSNY261F2L', 'B003OPCMZO', 5.0),
#  ('A2DTZUZK9YRJVK', 'B001ONTM3I', 4.0),
#  ('A1PI8VBCXXSGC7', 'B0029O10P4', 5.0),
#  ('A2KZRK2T9KFA0X', 'B001OCBTEY', 3.0),
#  ('AHRNDSKWH1YBT', 'B005T00LX2', 5.0),
#  ('A3T0OTH5072YRE', 'B004NPZYPY', 4.0),
#  ('A2SZLNSI5KOQJT', 'B003TC7WN4', 5.0),
#  ('A20MMCAHGALRAX', 'B00073IVAQ', 5.0),
#  ('A2ZY23X9IKXMON', 'B004T80BYE', 5.0),
#  ('A1E807WCM1PUP', 'B000G2UUOS', 5.0),
#  ('A4JS8BC0B8Z65', 'B000LKTSZ2', 3.0),
#  ('A38B7MUWO2UPZE', 'B00124WD1W', 4.0),
#  ('A2BN9DIBP9A0XG', 'B002LANN56', 3.0),
#  ('AQ55H30MZSV0Q', 'B0048KFVMU', 2.0),
#  ('AXA9EVY6IJIZ5', 'B0012EYELE', 5.0),
#  ('A1ZZZT0KJR46UV', 'B001EQ58GK', 4.0),
#  ('A2WK4JKR8S9SFL', 'B0000DBN1M', 4.0),
#  ('A37U44QN3A3DJN', 'B0042GUK94', 4.0),
#  ('A1HKBX2L0DV258', 'B000FW0NIC', 5.0),
#  ('AUVN6DFOBM27A', 'B000CQID2Y', 5.0),
#  ('A3TX8RH943OLBM', 'B0012XBD7I', 2.0),
#  ('A1ONZ8JRPLBNUI', 'B004YV80O4', 5.0),
#  ('A3QS4WWC1LCA6H', 'B006J4MAUE', 4.0),
#  ('A2G9M92C9FBUEP', 'B0009YYQZW', 5.0),
#  ('A2GEZJHBV92EVR', 'B003GZ24UA', 5.0),
#  ('A17V3UVYMI69TE', 'B0058AMY74', 4.0),
#  ('A867X78IJFE8H', 'B003AOMUJW', 5.0),
#  ('A5ZGPFG3I6O51', 'B006W5WDS4', 5.0),
#  ('AY12DBB0U420B', 'B000Q71L5U', 5.0),
#  ('AVTY5M74VA1BJ', 'B000WEPI1K', 3.0),
#  ('A39IW64JWDI7B3', 'B005G2FC2I', 5.0),
#  ('A1M5D4N88ZZM3S', 'B000OQ2DJQ', 4.0),
#  ('A3ODGAW5Z2EJ1M', 'B007FRD47C', 5.0),
#  ('A3ICXA05108QHJ', 'B001M050CU', 5.0),
#  ('AZXKAH2DE6C8A', 'B000IHJEDE', 5.0),
#  ('A1PZ7S1L36QRKJ', 'B001VIY8BW', 1.0),
#  ('A1EKF9JFF1XWSV', 'B002LANN56', 5.0),
#  ('A12GK5JUYAV0HM', 'B0018KR8V0', 4.0),
#  ('A1WX42M589VAMQ', 'B000FFRU3U', 4.0),
#  ('A2DQBXU2LEVWWA', 'B0058AMYTC', 3.0),
#  ('AFYOGGFSN48U2', 'B003561V40', 3.0),
#  ('ALAN629D6EKQZ', 'B000PDY3HI', 5.0),
#  ('A141XBYWBW40UC', 'B001BM6NIY', 5.0),
#  ('A3NO05U8A7GKF5', 'B0051ZCSB8', 5.0),
#  ('A2LJJ4482V9LAW', 'B001MUC1A4', 1.0),
#  ('A2EDTVVR9IFNLW', 'B004U43ZO0', 3.0),
#  ('A36FEPUTDN12KA', 'B002DMOY6O', 5.0),
#  ('A5CR6GP49HVEE', 'B00020HHGS', 4.0),
#  ('AQ80LJNDLVZPG', 'B0076MLL12', 5.0),
#  ('A1X036J0POA30A', 'B000FA3L24', 5.0),
#  ('A3AHDR4F2J7YXX', 'B0054TWQMM', 5.0),
#  ('A2RZUAFCLKAOLQ', 'B002QWP8H0', 5.0),
#  ('A1ZPY91VE3IDN1', 'B001GCVLVI', 5.0),
#  ('A1ZQI0ZOZ2AON9', 'B001ELL5OE', 5.0),
#  ('A1ZGHA3IJV01BK', 'B005HG9ET0', 3.0),
#  ('A2Q2GDB5XDYQV5', 'B002C4A70A', 3.0),
#  ('ATOYDAVYCK23O', 'B003MWBFMK', 5.0),
#  ('A1U3UICGCDNJYY', 'B000JFGHHQ', 4.0),
#  ('A29URW3C4M0IC2', 'B00125ZCWI', 5.0),
#  ('A2BVNVJOFXGZUB', 'B0045XE32E', 5.0),
#  ('AP8D74QD9LUUL', 'B005VOOKS8', 4.0),
#  ('AT0J9IP8XD95F', 'B000OH57ZW', 5.0),
#  ('A1JK3X941H3CKV', 'B001L1KHBY', 5.0),
#  ('A13C11C228TN5O', 'B0013BTP9C', 3.0),
#  ('ADUM14YVEGY8S', 'B003VIWN1M', 5.0),
#  ('A2X674TN3P7AVU', 'B00474CSVE', 5.0),
#  ('A1YPRLAFZLSAS0', 'B000OF71Y4', 5.0),
#  ('AY1EF0GOH80EK', 'B000HDK0D2', 5.0),
#  ('A5P60H1YBPXBE', 'B002TMV3CG', 3.0),
#  ('AUOA7P6T8JXSE', 'B000CQC0B4', 2.0),
#  ('A1IU7S4HCK1XK0', 'B0000DIYVM', 5.0),
#  ('A3JCSJC01SIAQX', 'B001BM01BE', 3.0),
#  ('A1O3ONM1MJM7EM', 'B003BJZMSM', 2.0),
#  ('A215WH6RUDUCMP', 'B002IEVJRY', 2.0),
#  ('A2SZWFJX0783BF', 'B002HFQS2K', 4.0),
#  ('A34Q3GVQ1CHUFT', 'B003VXFK44', 2.0),
#  ('A3FG4TRR8815R3', 'B000CQG8K8', 5.0),
#  ('A3TBTAX85OYRKP', 'B003EML8PM', 1.0),
#  ('A264XXAQG3ZV4A', 'B00141SO7A', 5.0),
#  ('APP5MBH2BSX6I', 'B004JRO1S2', 3.0),
#  ('A3SVNVNMCJW1FN', 'B003561V40', 5.0),
#  ('AA78TCLHXPJOK', 'B002T0KDNI', 2.0),
#  ('A1JISH2AQDW1YW', 'B005VOOL00', 4.0),
#  ('A30BST1JSB5211', 'B000EMPNCE', 5.0),
#  ('A11YOTONCPRQ9S', 'B000LKZK36', 2.0),
#  ('AY54QSGO3KWEM', 'B001E5DYC6', 3.0),
#  ('A2OWR2PL3DLWS4', 'B000CQG8KS', 1.0),
#  ('A1VHK2OGOCOSF5', 'B000CQC04Q', 5.0),
#  ('A2K3J2X8KDY47N', 'B001CHJ01A', 2.0),
#  ('A2CV33795L4KHH', 'B001Q9EFVY', 5.0),
#  ('A1IQV6AI7L9NOK', 'B005VOOLXM', 5.0),
#  ('A3KR0FZONNLRBC', 'B001RVFEP2', 4.0),
#  ('A13DOLMII1JPXC', 'B0029NU2E0', 5.0),
#  ('A1J75JJ0Q2OEJN', 'B004U49QU2', 5.0),
#  ('A2YM2NM7YZA24Q', 'B000WVY4PE', 5.0),
#  ('AKHFY3VCNZL2W', 'B000EUFAHO', 5.0),
#  ('APYKJUMZP99ZJ', 'B004JRKEH4', 3.0),
#  ('A2LASORRVJQI66', 'B002CJ9EPO', 5.0),
#  ('A18JI6XEQ6PQ3B', 'B000ZSX4D2', 5.0),
#  ('A2B2Z2QMVQWX5N', 'B000E243R0', 5.0),
#  ('ARBKYIVNYWK3C', 'B005HG9ESG', 4.0),
#  ('A3VBXQKRM7A4JR', 'B007RTR8UC', 5.0),
#  ('AQJBTS8BXNJ9N', 'B0013NUGDE', 5.0),
#  ('A1GVXO2ZZCGTMF', 'B0006MWNP2', 4.0),
#  ('A20F84KUBWM88B', 'B0061IUIDY', 4.0),
#  ('A1ZSF5CJ0A4CIO', 'B000G7V3K8', 4.0),
#  ('A2RPPG5T4Z1GOA', 'B000GFYRJE', 5.0),
#  ('A3N7IG2EQPMLXL', 'B0024SK3XU', 2.0),
#  ('A1WE8KTC20NY65', 'B004XELUBC', 1.0),
#  ('A2RERXI7RH3CIA', 'B000ER5DFQ', 5.0),
#  ('A1PI8VBCXXSGC7', 'B002IEZJMA', 4.0),
#  ('A1UFLVSJ3IRETQ', 'B000GFYRIU', 5.0),
#  ('AUMGVFDBLIC86', 'B008JKTH2A', 4.0),
#  ('A256PTZP0R81YR', 'B000WFN0VO', 4.0),
#  ('A26SYXM0IZMYPN', 'B000CNMGRU', 5.0),
#  ('A3SQV1Q3LQH59Z', 'B003LTKQFG', 3.0),
#  ('A1J95RXJED2NUZ', 'B0012BUR8Q', 5.0),
#  ('A2P5ZCMXDNMZKL', 'B002QWP8H0', 5.0),
#  ('A26LD9FQHTM8ZH', 'B006G7WCTI', 5.0),
#  ('A2H2DJS31WHEXP', 'B0029NVJ4M', 5.0),
#  ('A3REK3OFONWB1Q', 'B005VOONM6', 4.0),
#  ('A89ZZKNDFQH23', 'B000G2UUOS', 4.0),
#  ('AY3D7DG5L5WCK', 'B007RTR8T8', 5.0),
#  ('A9GIGJUB98JNR', 'B004L5NFT8', 5.0),
#  ('A1XS21L3D5GOZ4', 'B000Q7535Y', 5.0),
#  ('A33NXNZ79H5K51', 'B002N7DSLG', 5.0),
#  ('A3EXWV8FNSSFL6', 'B003GTR8IO', 3.0),
#  ('A2933AO5D7O1T6', 'B0058AMYTC', 5.0),
#  ('A2CBIQ9HMIQYQB', 'B00008CQVA', 5.0),
#  ('A2I98OOPNIJNYY', 'B004U49QU2', 4.0),
#  ('A1HRYC60VTMYC0', 'B001BCVY9W', 5.0),
#  ('A2OZ6PW2W5FQTP', 'B001Q9EGFY', 5.0),
#  ('AFDNACPVKXXPZ', 'B0009VO58S', 4.0),
#  ('A291HTT117RVS9', 'B004XGCXD4', 2.0),
#  ('A333ABL4WW067D', 'B0009VO58S', 1.0),
#  ('A39G2K0NEUXRYP', 'B001TM711E', 4.0),
#  ('A1080SE9X3ECK0', 'B001EPQCJ8', 5.0),
#  ('A2MNB77YGJ3CN0', 'B001RVFEP2', 5.0),
#  ('AQ1F3NP2G15S5', 'B001HN5Z4K', 4.0),
#  ('A219WUOP4BNUX1', 'B0030VJ8YU', 5.0),
#  ('AGDS7B4DRSSMF', 'B000WFUL3E', 1.0),
#  ('A2Y8IDC1FKGNJC', 'B000LL0R92', 3.0),
#  ('A1CVFUQ1PGSIJL', 'B000EUIZAI', 3.0),
#  ('A3D9Q8V4FGLA82', 'B0006VSXBG', 4.0),
#  ('A204QN2VRUQA9B', 'B001IZIBES', 5.0),
#  ('AY12DBB0U420B', 'B000CSKKG4', 5.0),
#  ('A3EJRBPUFFECQP', 'B000KV61FC', 3.0),
#  ('A31R4NEBHWLTJ1', 'B000VK8AVK', 4.0),
#  ('A32T2H8150OJLU', 'B0041CIR62', 4.0),
#  ('A22A1W41PJ1B81', 'B00427ZLOC', 4.0),
#  ('AYBYYDVV5ABJE', 'B0058AMYTC', 3.0),
#  ('A8WIWT45M3IGP', 'B001D0DMME', 4.0),
#  ('A3EXW4HNYX7HF5', 'B002IEVJRY', 4.0),
#  ('A1T1DXCJ7QAOMG', 'B002ANCDRI', 3.0),
#  ('A267FU71Z01CIH', 'B0051COPH6', 4.0),
#  ('A2I5QH4F5FDKK5', 'B001BCVY4W', 5.0),
#  ('A12BTR2MVK2BR5', 'B0029NLV8G', 4.0),
#  ('A2KZTED1RKELZX', 'B000I1PNR6', 5.0),
#  ('A79372WBA9IJM', 'B001EQ5MS4', 5.0),
#  ('A105S56ODHGJEK', 'B004R8J8EK', 5.0),
#  ('A1X1CEGHTHMBL1', 'B002HQKID4', 5.0),
#  ('A3AZ8ZRNK2SS07', 'B000LKTXQG', 5.0),
#  ('A10YSUFFO9MXTJ', 'B004HOQE64', 5.0),
#  ('A1ED84P4RIOJ2Z', 'B0029K68ZK', 2.0),
#  ('A1Y27QQ772FT0I', 'B001EQ4QJK', 3.0),
#  ('A3IR834T7AROBT', 'B003VXHGDM', 5.0),
#  ('A1K82R24ROO2I7', 'B000EPUPSS', 5.0),
#  ('AYQ8RLE0K6RU8', 'B0002DJNJO', 4.0),
#  ('A3NOS22H78I2O3', 'B00292BM7C', 1.0),
#  ('A3A0DJF0OK1JUM', 'B001NXHY8Y', 5.0),
#  ('AE5A0AOJOAZJO', 'B005258A2I', 5.0),
#  ('AMRMK86X3PKXD', 'B0045TI2HU', 5.0),
#  ('A2WUNBOM5RIYEH', 'B000WVY4PE', 4.0),
#  ('A2TBNGM7LN3CIR', 'B000AYFCEU', 1.0),
#  ('AE9LVM0KKA8RW', 'B000VJYTZM', 5.0),
#  ('A2UIVSCVH5S6H3', 'B00375LB5I', 5.0),
#  ('A2JKD2KFHGTJB3', 'B001AWBL5U', 5.0),
#  ('A2YW1MG1GKU8XD', 'B004DIR3TQ', 5.0),
#  ('A1TMAVN4CEM8U8', 'B000PMJLJO', 3.0),
#  ('A3EFSLEMHNPP6A', 'B000FBOAOQ', 5.0),
#  ('A2YB7DLC3FOR7W', 'B001DWEZYQ', 3.0),
#  ('A3LQS08K2OBI5Z', 'B003VXHGE6', 3.0),
#  ('A2OL5WLCNZVD9K', 'B005VOOKS8', 5.0),
#  ('A1JMCY0XKUXT6X', 'B0013QRY18', 5.0),
#  ('AQ8DU6XVA3USJ', 'B006Q7YG24', 5.0),
#  ('A2A8KWCE8RKB9T', 'B000EQT4MA', 5.0),
#  ('A25C2M3QF9G7OQ', 'B0001EQN88', 5.0),
#  ('AAVXLDJPBOJBW', 'B001EO5QPA', 4.0),
#  ('ADB6MLJ02UXWJ', 'B004T0DLQW', 5.0),
#  ('A2N0XGXKS9KTCK', 'B00073IVAQ', 5.0),
#  ('A2K45OG1G1E48B', 'B001WJV7L4', 5.0),
#  ('A73DFWJE0CGY6', 'B007JFXWRC', 5.0),
#  ('AVJRM7O2WBWEZ', 'B003M61F4E', 5.0),
#  ('AQXJM6TILVEDY', 'B003D4MW38', 5.0),
#  ('A26MBVPPXZN1YM', 'B005VOONGM', 5.0),
#  ('A2DM3CQ3WYA8DW', 'B004HOOZEW', 5.0),
#  ('A307YFSORUAXSQ', 'B0002PSOJW', 5.0),
#  ('A20XWDZHAXIYOK', 'B0029NV500', 5.0),
#  ('A2K75QOCP9ZHSL', 'B0051COPH6', 4.0),
#  ('A3V3J0WT6HUR16', 'B001E52VR0', 5.0),
#  ('A3HQAPXAJV7PRX', 'B000633WEW', 4.0),
#  ('A2RKI7RPP5CJMG', 'B005VOONM6', 4.0),
#  ('A2TO2BN3P4C00L', 'B000YSRK7E', 3.0),
#  ('A13MKSASQ6YWL7', 'B001AVC49S', 5.0),
#  ('ATZ0P4653KL13', 'B0058AMY5G', 2.0),
#  ('A1SZG52GFZYEUX', 'B003G52BN0', 3.0),
#  ('A29QXI9MWCVO7Q', 'B000ND7E7G', 4.0),
#  ('AW6J9IILGOZY3', 'B002D4DY8G', 3.0),
#  ('A5FVX0Z1KT6D4', 'B0014EUAA6', 5.0),
#  ('A25RTRAPQAJBDJ', 'B004R8J8E0', 5.0),
#  ('A1ZQP22BB28R02', 'B000WFU8O6', 5.0),
#  ('A1R9QOPV6HVEKF', 'B001EO6ABO', 5.0),
#  ('A2GLD72HQYHG0P', 'B001BCVLG8', 4.0),
#  ('AE2MKYLMTYF21', 'B004R8J8E0', 5.0),
#  ('A3III07Y9VJI8Q', 'B003Q4TZ12', 5.0),
#  ('A3T0OTH5072YRE', 'B007M83302', 3.0),
#  ('A1G9J1LJ6K5501', 'B003RRFBB6', 5.0),
#  ('A1PMWT1I668I15', 'B002NHYQAS', 5.0),
#  ('A1X5MDUC3A2PV6', 'B0034EDMCW', 5.0),
#  ('A2P0JC3HKUETS3', 'B002BCFHTY', 2.0),
#  ('A1Z4LX3Q1YMF84', 'B0043OV02Q', 5.0),
#  ('A22Z9R91N8L7IQ', 'B000FA15RW', 5.0),
#  ('AIRH7SDIXGSAF', 'B000UBMO4Y', 5.0),
#  ('A34NM4QLI46S8F', 'B0034EDMLI', 3.0),
#  ('A1IY4JN9XWCYBA', 'B001KVPBS4', 5.0),
#  ('A1PDSOTIRL4Q3O', 'B004IJHY4Y', 3.0),
#  ('A1YRMZSCQJC6BL', 'B006N3IG4K', 5.0),
#  ('AZAKCIFE27RAA', 'B001BM62T4', 2.0),
#  ('A3UR5KVANJF2W3', 'B001EO5TIE', 4.0),
#  ('A1D8ND2ES00NJG', 'B0002DJ34Y', 3.0),
#  ('A2DI7UGT3YX4Q9', 'B004ZIER34', 5.0),
#  ('A2ABD9X340BR3I', 'B0013NUGDE', 5.0),
#  ('A19IIHI8GB61CV', 'B000WVY4PE', 5.0),
#  ('A1K6G7NNTKGKT0', 'B001BS4G6O', 5.0),
#  ('AQ5DOLCW77FEE', 'B00269E5C2', 3.0),
#  ('A1O8B2WYDCPTIQ', 'B000FVDWU4', 5.0),
#  ('A3ARZW7S96SESC', 'B0058AMYTC', 1.0),
#  ('A29313797NGT9L', 'B000EH0RTI', 4.0),
#  ('A2O421DTA8J0RW', 'B005EF0HU4', 5.0),
#  ('AMC708Y8VAWSO', 'B000E123IC', 5.0),
#  ('A1WOMXOEX90ARI', 'B001E5E3JY', 5.0),
#  ('A2MIP3AQVSF2SS', 'B000VZJIVG', 4.0),
#  ('A1L1S42BOGPF96', 'B0029K32YU', 5.0),
#  ('A1Y8IUMN7TBKS', 'B000KFY0P6', 3.0),
#  ('A28CAC7AAFWAXF', 'B0053B7BXU', 5.0),
#  ('A1FNVXNEPWBZRR', 'B002C1WE5O', 4.0),
#  ('AQ8DU6XVA3USJ', 'B001BDDT8K', 5.0),
#  ('A36WGHR8TO5DKT', 'B0029JW8T6', 4.0),
#  ('A198JRUIP09HX5', 'B000H5DADW', 4.0),
#  ('A18L1CVUIQRE9L', 'B000RHUW18', 5.0),
#  ('ADEZOPMPKK146', 'B001LGGH54', 3.0),
#  ('AC9JAT85740ME', 'B005RGZO2G', 5.0),
#  ('A1SV0Z7UZ15SPJ', 'B000CQG87Q', 5.0),
#  ('A219WUOP4BNUX1', 'B0030VJ8PE', 5.0),
#  ('A39GSBHR6509MV', 'B000WFLXWW', 3.0),
#  ('A38RWVWOQPYJSA', 'B008ADQPEO', 5.0),
#  ('A3BCR90WBKKTFY', 'B0012KIBCQ', 2.0),
#  ('A3J3T04O95XU4Y', 'B000EH0RTI', 5.0),
#  ('A13QM0HT6VXHL5', 'B001EO6122', 4.0),
#  ('AF3ARXQTCC4B4', 'B001EO5TJ8', 2.0),
#  ('A1G60ANYI0HMEU', 'B004HOLD92', 5.0),
#  ('A1D8ND2ES00NJG', 'B000QSON4K', 3.0),
#  ('ABXU3VKU4A0T2', 'B0030VJ9K8', 5.0),
#  ('A2FKNAOSP2965J', 'B002ESS6RK', 5.0),
#  ('A7OLST5USCDGU', 'B004D0U26A', 5.0),
#  ('A233H2J16V56W8', 'B001E6J07I', 5.0),
#  ('AAUICTIUBVU7R', 'B001E5DZJ8', 1.0),
#  ('AG6TX1ZJHLMO7', 'B008O3G2K2', 3.0),
#  ('A2OP7RW3WNXR6C', 'B001SITYJ6', 5.0),
#  ('A221I9R7I92ORO', 'B004S07G1Y', 4.0),
#  ('AQ4HZSQLCAWNA', 'B000CQID2Y', 5.0),
#  ('A2R1HUYHXV7H18', 'B001AHJ2D8', 5.0),
#  ('A1B1QMGK8VYG80', 'B0013NUGDE', 4.0),
#  ('A3H9JSM1SUTE4O', 'B0014WYXQK', 4.0),
#  ('A1YFI21CFKYV5I', 'B0014AUJII', 5.0),
#  ('AWCHFZ05FPJYH', 'B003AYH560', 3.0),
#  ('A2MQ6I7OOCTHZD', 'B000LKXHUY', 5.0),
#  ('A1DN8OM1DDSFUC', 'B001E5E3IA', 5.0),
#  ('A3W2MCLG5VA7DH', 'B001E0TBA0', 5.0),
#  ('AJBPCCJLSNO3H', 'B001EO77FW', 5.0),
#  ('A2OIVQN4WS608Z', 'B000CQIDHE', 5.0),
#  ('A2CJMKLNC0G1SE', 'B000CQIDAG', 5.0),
#  ('A39D7ONPOORMUT', 'B002IEVJRY', 5.0),
#  ('A1YKVTUDRNJZ7', 'B000ILI60M', 1.0),
#  ('A18V316U2HXALE', 'B0013QQ4UA', 5.0),
#  ('A1TNUUSBLUSVZF', 'B008AV5HLS', 5.0),
#  ('A15RT5XOD85Q29', 'B002KLLHF4', 1.0),
#  ('AKZKG2Z7CNV27', 'B000634D0O', 1.0),
#  ('AG1JWQCP2UKI7', 'B000MQ60LK', 4.0),
#  ('A3Q15HWNS6GOEH', 'B007OXJKF2', 3.0),
#  ('A3RJXPM2K47F5O', 'B000EDGBF6', 5.0),
#  ('A2K4Q4I8MPUMQU', 'B001EO6604', 5.0),
#  ('A2J8I1HP264IPC', 'B000HS23TQ', 5.0),
#  ('A13MKSASQ6YWL7', 'B000Q611U6', 5.0),
#  ('A18GJ9MYYO6GCQ', 'B00112XJUY', 5.0),
#  ('A3L3HI0ECONAD2', 'B001TM70V0', 5.0),
#  ('A5KMMY627T3W', 'B001VJ0B0I', 5.0),
#  ('A3SWCA2NEHRL0Z', 'B002GWHFMQ', 3.0),
#  ('A2YJAVXQQ561YY', 'B006N3HZ6K', 5.0),
#  ('A1DRM3JV6T5O6P', 'B002TSA91G', 3.0),
#  ('A3R9HB8CS84AZO', 'B000AY9UBQ', 5.0),
#  ('A1LNMX0VCOU7XK', 'B000F9Z1WI', 5.0),
#  ('AVJV35095JH71', 'B001PMC3PM', 5.0),
#  ('A2T0NT5M6GSDHW', 'B001E0TBA0', 5.0),
#  ('AMFVLGQSV1X3R', 'B000W5SLEU', 5.0),
#  ('A1MGP9NZQ5V7KU', 'B000EQT4MA', 2.0),
#  ('A2P1RL8TY0BT10', 'B000VK8AVK', 2.0),
#  ('AVFJ327UXPXLF', 'B00271OPVU', 5.0),
#  ('A2HJPG1L877M73', 'B0012BUR8Q', 5.0),
#  ('A1HOXKR7OKJ1X1', 'B002MNYD4M', 4.0),
#  ('A3UW0PQLDUACMH', 'B005VOOM2W', 5.0),
#  ('A3ULJE7UMUGSXR', 'B005VOONM6', 4.0),
#  ('A3502W435NLGAZ', 'B003VXFK44', 5.0),
#  ('A30H2335OM7RD6', 'B000G6O2QG', 5.0),
#  ('AJE5S2MH4SERA', 'B000EQT574', 5.0),
#  ('A28GM84ZIMNP4A', 'B001F0RJIK', 5.0),
#  ('A1FP5ZLSKR07SU', 'B000J39TSW', 5.0),
#  ('A39ISGPKMF9X0R', 'B004FELBH8', 5.0),
#  ('A2SZLNSI5KOQJT', 'B005ZZHT36', 3.0),
#  ('A136VAVDIU9DOU', 'B001FZ0SVA', 5.0),
#  ('A2K75QOCP9ZHSL', 'B007RTR9G0', 1.0),
#  ('A1N6712C6JHYJ9', 'B0029JW89Q', 5.0),
#  ('A2A5MBGYJUXTD0', 'B002AR14WO', 5.0),
#  ('A2I98OOPNIJNYY', 'B0040K41MY', 4.0),
#  ('AB0Y33G717HOU', 'B005SPH780', 4.0),
#  ('A2QM9IE3S9ZZL3', 'B001E5E25Y', 5.0),
#  ('A31HE83MU98GBV', 'B001NXHY8Y', 5.0),
#  ('A1LL8N425UTUM6', 'B001EO5W2M', 1.0),
#  ('AT9U5ZE5OO84C', 'B001AHL6CI', 5.0),
#  ('A18UVHCREY2RE2', 'B002ULC3KW', 5.0),
#  ('A2YMZM2WJS9C0L', 'B002OVS8KW', 5.0),
#  ('A2VF3XTT7245RE', 'B000GB3NS4', 5.0),
#  ('A37CU57W3ULVJG', 'B0019FM29M', 2.0),
#  ('A29IPF6KF8D5YW', 'B004M0LLHU', 3.0),
#  ('A33X80DIINN48Y', 'B008RWUKXK', 3.0),
#  ('AKMEY1BSHSDG7', 'B000I60JUW', 5.0),
#  ('AYNAH993VDECT', 'B002D4DY8G', 4.0),
#  ('A2IVB6L8GQY2TV', 'B001TLY7BM', 5.0),
#  ('A2YSFKX18XTHED', 'B000EFHST2', 1.0),
#  ('A74SHV5ZD3RLT', 'B003MI2ATQ', 5.0),
#  ('A361PLXEWB9UC1', 'B000RJVO0O', 5.0),
#  ('AVIYHPBLQVBGB', 'B003C5THEK', 1.0),
#  ('A3QEHWN3OGC8FC', 'B000WVYB8Y', 1.0),
#  ('A1FRQ3XAZAK4G3', 'B001SITWC0', 1.0),
#  ('A1E5F4L4PC6QNA', 'B0002I0GUY', 5.0),
#  ('A1BC7V7RWX9HEY', 'B003AYGMNC', 5.0),
#  ('AEUZL4VESZIUR', 'B0049Z9ANU', 5.0),
#  ('A4QXTN3K865NR', 'B000YSTIL0', 5.0),
#  ('A2PRQHCIDISMM4', 'B00422FURA', 5.0),
#  ('A30LWRPQ3EG0IG', 'B001PMDYZA', 5.0),
#  ('A2CZ98V784SRJ0', 'B008O3G2GG', 3.0),
#  ('AL3E5V6MXO9B0', 'B00126AQB4', 5.0),
#  ('A2M9D9BDHONV3Y', 'B0041SLGSW', 1.0),
#  ('ARAKTT5M3DDYA', 'B001CU0N9K', 4.0),
#  ('A2II09GQGWOMTQ', 'B00060NVW8', 5.0),
#  ('A2YB7DLC3FOR7W', 'B0026KNQSA', 5.0),
#  ('A1NKKF4W2LHF6M', 'B005VOOL00', 5.0),
#  ('AJS7THAS9CZ59', 'B003VXL0V6', 5.0),
#  ('A2HJPG1L877M73', 'B004OQBC8K', 5.0),
#  ('API5JLBRT6FIN', 'B001EO77FW', 4.0),
#  ('A3KWRPM3DWXNXW', 'B0009VO58S', 5.0),
#  ('A3FWSAIGXQPJUJ', 'B002HFRAN6', 5.0),
#  ('A4DXE5ZVH1RBW', 'B004SVIK5O', 5.0),
#  ('A3FBMSWBJ202SF', 'B004OV6X6Q', 5.0),
#  ('A250FFYP8R4OMJ', 'B000VK4F5A', 5.0),
#  ('AQ6AGWKWMTY8H', 'B0061IUKDM', 4.0),
#  ('AJ2PPTWZ0IIJS', 'B004YGQPAK', 4.0),
#  ('A3JUM0WSKPN0NT', 'B00020HHM2', 1.0),
#  ('AINMG64N0CBEG', 'B000CQC050', 2.0),
#  ('A1WP940JZL83T7', 'B0043XJREA', 5.0),
#  ('AXE7T4A3Y8DPB', 'B0013NUGDE', 5.0),
#  ('A3SIXO7D5FFA5F', 'B001D0DMME', 5.0),
#  ('A1KSDKIZ4XN3GG', 'B001OCKIP0', 5.0),
#  ('A26DCH8BNG0BTO', 'B003PFWPG4', 3.0),
#  ('A291HTT117RVS9', 'B002ZJ4IYI', 5.0),
#  ('A1RPVOVIXVQ2TU', 'B000X1Q1G8', 1.0),
#  ('A1UQBFCERIP7VJ', 'B005GWYMTW', 4.0),
#  ('A6GMEO3VRY51S', 'B0000GIVEQ', 5.0),
#  ('A178DX34IA85M1', 'B003YK72LS', 5.0),
#  ('AID3D20YLGU0U', 'B003QNJYXM', 5.0),
#  ('A3VD6KREW99X02', 'B004X2LH9Y', 1.0),
#  ('A153HSQ6QAFXDQ', 'B00020HHGS', 4.0),
#  ('A1IU7S4HCK1XK0', 'B000LKXQRS', 1.0),
#  ('A1LERBW69A3FDS', 'B0012XBD7I', 3.0),
#  ('AT66IKVKXSI46', 'B000GZ3B1O', 5.0),
#  ('A250GXRD2BGQV2', 'B000IMYNIA', 5.0),
#  ('A1JFXOFDRZ9CFQ', 'B001396HZE', 5.0),
#  ('A3JA8EXHWOUV6M', 'B004W3CXC4', 5.0),
#  ('A10B49ZO696DLO', 'B000EQYW0E', 5.0),
#  ('A3NXBP212KFH5X', 'B000LKVD5U', 5.0),
#  ('A3SMD3T0QTN109', 'B002IEZJMA', 4.0),
#  ('A3OJX18B60PJR9', 'B006BXV1H6', 4.0),
#  ('A10QQ7QAW8MIEV', 'B003YK72LS', 5.0),
#  ('A2F36UHYTDH80A', 'B000CQC04Q', 5.0),
#  ('ARTST8JB04TBC', 'B005VOOM4A', 5.0),
#  ('ANFHMVAHGX0J1', 'B000WFU8O6', 5.0),
#  ('A1EBHOTIC6DUZ', 'B001RVFERK', 4.0),
#  ('A2JP9E1H0SF392', 'B003UI9R8K', 5.0),
#  ('A1GOL6RSTISMN5', 'B001GKV8DQ', 5.0),
#  ('A2YMS9UK1A9OF2', 'B000LQNK5A', 4.0),
#  ('A1OWRLSD7LTSQ9', 'B002IEZJMA', 4.0),
#  ('A3SDNUDDM21A5F', 'B000CQBZQK', 5.0),
#  ('A1UASXJKH475MV', 'B003BJZMSM', 3.0),
#  ('A2OWR5G2OAQF7C', 'B001EQ4KYQ', 5.0),
#  ('A9TPV4O2YQJXO', 'B005NPE9FO', 5.0),
#  ('A1TQQQAYEDEY6B', 'B000OH57ZW', 5.0),
#  ('A35Q0RBM3YNQNF', 'B002IEZJMA', 5.0),
#  ('A3EIOMC103PG7W', 'B0040WG0QM', 5.0),
#  ('A2GEZJHBV92EVR', 'B000Q6KUV2', 5.0),
#  ('A3OXHLG6DIBRW8', 'B000EMM9WG', 5.0),
#  ('A1VOVSS040NHKD', 'B002AK88SY', 5.0),
#  ('A2L1Z55GVXM1AF', 'B001EO5OKC', 4.0),
#  ('A2ASEKR0NI5EK5', 'B002OFUC8O', 1.0),
#  ('AUMGVFDBLIC86', 'B000I6KQ8W', 4.0),
#  ('A1LNMX0VCOU7XK', 'B002QGZ7AE', 5.0),
#  ('A3JPFWKS83R49V', 'B001OCBT3U', 4.0),
#  ('ABAHKMFEHT8K1', 'B002ZOCF0M', 5.0),
#  ('A2ZE8BSZ5MMEOP', 'B001E5DXD6', 5.0),
#  ('A2G6AVBZ2OPFJX', 'B0014ATRV8', 4.0),
#  ('A27O5ZUFAEWT9L', 'B005VOOKS8', 5.0),
#  ('A1YGCU0QQKZC29', 'B003161EV4', 5.0),
#  ('A14RZUPW44KCPF', 'B001397WYY', 5.0),
#  ('A3BZCJS4NORJQW', 'B0041NYV8E', 3.0),
#  ('AJMY77NAPOLQ1', 'B001SITXH4', 4.0),
#  ('A2NOW4U7W3F7RI', 'B004YUF89K', 5.0),
#  ('AEBK6CTXMBCFY', 'B0087ACS5A', 5.0),
#  ('A28CCN6VYHRUKS', 'B001Q9EGFY', 5.0),
#  ('A2AVYSXICESSTK', 'B001ELLBJS', 5.0),
#  ('A6UFSCD6O8JMT', 'B000LKXBL4', 4.0),
#  ('A15RT5XOD85Q29', 'B000WMU2HM', 4.0),
#  ('A147FUNITGB21I', 'B005VOONLW', 4.0),
#  ('A267FU71Z01CIH', 'B004JRO1S2', 4.0),
#  ('AV6G07JV1P9YC', 'B000WVY4PE', 3.0),
#  ('AYWUHB7N8XGZQ', 'B001EPPSYI', 5.0),
#  ('AYBCQ12Z5ZPQG', 'B0025YTELA', 5.0),
#  ('A2EXT8FXO9E24E', 'B008FHUCNU', 5.0),
#  ('A16J84BXTPH30', 'B0002DGRSY', 5.0),
#  ('AXOO7BPM22BDO', 'B004YV80O4', 3.0),
#  ('A12L1NY994GXSF', 'B001B4VOQI', 5.0),
#  ('A3LA7JFUWHKBEW', 'B0026KNQSA', 5.0),
#  ('AT53ZTTO707MB', 'B0053H9SKI', 5.0),
#  ('A3S15YGZ6W6EV2', 'B004INMOUE', 4.0),
#  ('ACO1YBDX803ZW', 'B000OQ2DJQ', 4.0),
#  ('A18IZ3RTL9SD4V', 'B005VOONM6', 5.0),
#  ('A2MSAEEPBU81I6', 'B004IY1MGU', 5.0),
#  ('ANRJ7OJLB3NS1', 'B001EO5Q64', 5.0),
#  ('A1EX5SK2PD0XLC', 'B0083QJU0O', 5.0),
#  ('A1QRA8XPFUEKW5', 'B00020HHGS', 5.0),
#  ('A3UUTDX2WNVUS3', 'B000K8V1PA', 5.0),
#  ('A3UCO7B9HP42BG', 'B000Y2AICY', 5.0),
#  ('A39LURR2WD1FLL', 'B0029NTQ1K', 4.0),
#  ('AM8W6Y3HVXLZT', 'B001OCKIBY', 5.0),
#  ('A1RXLZY53ZQ6UT', 'B001CGTN1I', 5.0),
#  ('A16AXQ11SZA8SQ', 'B002R8SLUY', 5.0),
#  ('A1385FE19O0301', 'B000JFFO8O', 1.0),
#  ('A1G60ANYI0HMEU', 'B001EQ55RW', 5.0),
#  ('A2AOZQ3WTNVVOK', 'B002ZJSWO0', 4.0),
#  ('A2CPM6WTF7PO3G', 'B003WGJ0OQ', 5.0),
#  ('A1HRYC60VTMYC0', 'B001QXC8E6', 5.0),
#  ('A3B2KMJ5J2G7NG', 'B0002MLA5K', 1.0),
#  ('AY12DBB0U420B', 'B000YPIJ0Y', 4.0),
#  ('A1O1OQ5VS0OCNI', 'B000IEC66E', 5.0),
#  ('A1MRRMHGV3PN5W', 'B005BPVE90', 4.0),
#  ('A3J6TE3SKSYBUI', 'B0092VQOTE', 4.0),
#  ('AYI1BCOMQXSWI', 'B0012BUR8Q', 5.0),
#  ('A1EMN4T3ROJDOO', 'B005VOOM5E', 5.0),
#  ('A1PG93QIDD9CV7', 'B0041SZEHQ', 4.0),
#  ('AEC90GPFKLAAW', 'B005GBIXZM', 3.0),
#  ('A2CV6KXDKFYIN1', 'B0007A0AQW', 2.0),
#  ('A3T8WOFS5RD2IR', 'B007JT7AEY', 4.0),
#  ('A1QXE7OX7MSL2H', 'B000ALGNHI', 1.0),
#  ('A3A7Y3TSPPZU9T', 'B002IEZJMA', 4.0),
#  ('A1X2LENOF84LCQ', 'B00248EE4O', 4.0),
#  ('A3HOGJ49XCSCW7', 'B005IW4WFY', 4.0),
#  ('A1JTQCIL88W9JV', 'B0029JW8T6', 4.0),
#  ('A1F7SX3GNVBNE3', 'B000EISJXS', 5.0),
#  ('A1EKF9JFF1XWSV', 'B0090X8IPM', 5.0),
#  ('AYB4ELCS5AM8P', 'B001FA1DUA', 5.0),
#  ('AEL6CQNQXONBX', 'B005VOONI0', 5.0),
#  ('A4DXE5ZVH1RBW', 'B000OF7XL0', 3.0),
#  ('A2WE93LJX8PMT1', 'B001VJ0B0I', 5.0),
#  ('A1ZK5P0EOE727F', 'B001BOE3UW', 3.0),
#  ('A39Z97950MCTQE', 'B001EQ5NJM', 3.0),
#  ('A2RFJYQ08USWOG', 'B000FBM3WC', 5.0),
#  ('A35OHTADORNP7N', 'B006N3IG4K', 4.0),
#  ('A3EURGOIEBJWKD', 'B005VOONM6', 5.0),
#  ('ATUE65UINXBXK', 'B0001BGTYE', 5.0),
#  ('A1SI2993YY7C61', 'B005VOOM4A', 5.0),
#  ('A30H2335OM7RD6', 'B0010UOGWM', 4.0),
#  ('A12PN254PTSGU5', 'B005GBIXZM', 4.0),
#  ('A16CA0LWKNZ2OL', 'B001E5116C', 5.0),
#  ('AJQDIT55SZ3ZX', 'B000AYGXKC', 5.0),
#  ('A2I05FGBTCRRB8', 'B006Q7YG24', 4.0),
#  ('AF5P64O9835IZ', 'B003SSWCJI', 5.0),
#  ('A3NID9D9WMIV01', 'B001R3BQNY', 5.0),
#  ('A25VFHVGI4CFTP', 'B002J6PBRU', 1.0),
#  ('ANDN9BU8C5XWN', 'B0029NS7BU', 5.0),
#  ('A2PZCSXQLU4I4G', 'B000CQID2Y', 5.0),
#  ('A1SINHLUYMCCRK', 'B005VOONM6', 3.0),
#  ('A21XUSS7STBPPY', 'B001EO5U8I', 5.0),
#  ('A1HOXKR7OKJ1X1', 'B006JUV0S6', 5.0),
#  ('A198DOHB5Y97TX', 'B000WFKI82', 5.0),
#  ('A2FVD05Z2FYW1P', 'B005QRPHSW', 4.0),
#  ('A2XKJ1KX6XUHYP', 'B005CD2T4U', 4.0),
#  ('A1MRRMHGV3PN5W', 'B0054TWQ2C', 4.0),
#  ('A3O4HTMFGLLY8B', 'B00099XNZ6', 5.0),
#  ('ANZJL6D04BTNY', 'B000Q71L50', 5.0),
#  ('ABPZ330FEQ1GM', 'B000CQC05U', 5.0),
#  ('AJD41FBJD9010', 'B0002DGRQ6', 5.0),
#  ('A36PG3D7ILZEU2', 'B001EQ51YE', 5.0),
#  ('A3DWGIDZUA8PE7', 'B001E5E0Y2', 3.0),
#  ('A1F7YU6O5RU432', 'B007RTR8T8', 4.0),
#  ('A18RJKCYAW9RJP', 'B008JKSJJ2', 5.0),
#  ('A3HPCRD9RX351S', 'B0042Q7E7K', 4.0),
#  ('A3UR5KVANJF2W3', 'B001E5E268', 4.0),
#  ('ATMJL2BG7S6NP', 'B000WFPJIG', 5.0),
#  ('A2RHV42BTJSVON', 'B005VOONI0', 4.0),
#  ('A3M8R4JD1SIS76', 'B0005XO2ME', 5.0),
#  ('A2HL2BY512HTVQ', 'B005K4Q1VI', 2.0),
#  ('A3HTMUB72A5P79', 'B000ZT15EQ', 1.0),
#  ('A17KZ1MF2V6B4Y', 'B0013L92Y0', 4.0),
#  ('A39EQRLJQJ51BM', 'B003D4F1QS', 5.0),
#  ('AC57A1QMUXK10', 'B001EQ56Y4', 5.0),
#  ('A3IG444HB0PTFG', 'B000CQC08C', 5.0),
#  ('A2JZVE0Y19VLL0', 'B001BLXRPC', 1.0),
#  ('A1RUS8VOWCIC28', 'B006WYSFZK', 1.0),
#  ('A1UDFKEKTO70NX', 'B000GWLR72', 4.0),
#  ('A2T135XHAH82S4', 'B000H27NWO', 1.0),
#  ('A3S87ZOPB3UM9N', 'B004IRCHKW', 5.0),
#  ('A2XCVFS4DJRBDF', 'B000BF3AII', 1.0),
#  ('A1GYEGLX3P2Y7P', 'B004E4HUMY', 4.0),
#  ('A33HIQR1X1G4GI', 'B005VOONKI', 5.0),
#  ('AQZH7YTWQPOBE', 'B0076YVPWU', 4.0),
#  ('A2RHV42BTJSVON', 'B005VOOL00', 4.0),
#  ('A3TAS1AG6FMBQW', 'B001ASAT4S', 1.0),
#  ('A1N655X9X7C6QY', 'B001EPQZAE', 5.0),
#  ('AX0ZTNX6KVJ40', 'B005A1LJ04', 2.0),
#  ('ATUXNR3WHD18N', 'B00020HHGS', 4.0),
#  ('AOR52NN9OR1QK', 'B000FAIR96', 5.0),
#  ('A1RPVOVIXVQ2TU', 'B003561V40', 4.0),
#  ('A3QDITMY3OOYRP', 'B0030F70LO', 5.0),
#  ('A2N1WT1EBTWTBV', 'B000EQYQBO', 5.0),
#  ('A2YW1MG1GKU8XD', 'B005VOONM6', 3.0),
#  ('A2I98OOPNIJNYY', 'B004YV80OE', 3.0),
#  ('AACHTQHK9Z9MX', 'B001BM3C4M', 1.0),
#  ('A3042WJDYJ22S8', 'B001EO6F6Y', 5.0),
#  ('A2OMQEK9OW2FY6', 'B004MO6NI8', 3.0),
#  ('A3NEAETOSXDBOM', 'B002ZX1U9A', 5.0),
#  ('A2KQT4D0OZR569', 'B003TO9RSU', 5.0),
#  ('A1989WJVG7DHBK', 'B001L0677S', 5.0),
#  ('A32Y5L6MQ62KM8', 'B002GOYT1O', 5.0),
#  ('A3OXHLG6DIBRW8', 'B0070SGNS8', 5.0),
#  ('A14H5GNH2EIPAC', 'B001EO6GU4', 4.0),
#  ('A25CGBLRJB6X0S', 'B001EQ56T4', 5.0),
#  ('A353U0L2HAMSHV', 'B002FC6JZG', 4.0),
#  ('A1LERBW69A3FDS', 'B0058AMY10', 3.0),
#  ('A26JYIPTHH25VC', 'B0029NGY4M', 5.0),
#  ('A1HXWVK7RKR4D2', 'B0033GMSTY', 5.0),
#  ('A29U4102KKI5U9', 'B0038B38BQ', 3.0),
#  ('AZV26LP92E6WU', 'B0025UAC4M', 5.0),
#  ('A2GOTW3U8IIR7J', 'B000CQIDHE', 4.0),
#  ('A2NPOQXJDJVN0W', 'B0029XLH4Y', 5.0),
#  ('AQH1SWR5HA413', 'B005VOONLW', 5.0),
#  ('A2OY3MCJQSRSUO', 'B004BJVLWC', 5.0),
#  ('ABAQ9SKKJ8Y67', 'B000LKVRVA', 5.0),
#  ('A3HPZ6BIMNXSZR', 'B0018KR8V0', 4.0),
#  ('A38AKD7TL2WWCR', 'B000PG1D1O', 1.0),
#  ('A34W7QA4J5UTOR', 'B001OCKIBY', 5.0),
#  ('A36E68YOWHTIDN', 'B004X8TGUK', 5.0),
#  ('A1YGIUSI2JTTSC', 'B005QRPH3M', 5.0),
#  ('A59128KLN4BQK', 'B002QWHJOU', 5.0),
#  ('A3PI8JJ2E4VT5E', 'B000FFLHU2', 5.0),
#  ('AT9U5ZE5OO84C', 'B001E5E1WS', 5.0),
#  ('A2N5YX7DLGPG3K', 'B002T0IHJ0', 5.0),
#  ('A3W4D8XOGLWUN5', 'B006BXUZVO', 4.0),
#  ('A3HS7FAIHHW998', 'B0006345PW', 3.0),
#  ('A2NYK9KWFMJV4Y', 'B000HQPNZY', 5.0),
#  ('A3QN6CZK31WU7P', 'B004HOLD92', 5.0),
#  ('A3A90CELVLOUP6', 'B007M83302', 2.0),
#  ('A2J8E7CIR06F5V', 'B008GRIB0A', 5.0),
#  ('A3TP31S61PPE3G', 'B006BXV1H6', 4.0),
#  ('A2YQ2ZI65F37N8', 'B0041NYV8E', 4.0),
#  ('A17CQORLF0JIFL', 'B005VOOM4A', 4.0),
#  ('A2W4014S06NAIT', 'B004E4EBMG', 5.0),
#  ('A2I2A7N3OCPNW4', 'B005XB5K0G', 5.0),
#  ('A3HHRQBSECP697', 'B002HQLY7S', 5.0),
#  ('A23HRTD9I9K90Z', 'B005JTMF0U', 2.0),
#  ('A2WURA7XS1L00T', 'B002T0GXNC', 1.0),
#  ('ALWUWI6PESIXU', 'B002HFWMOI', 5.0),
#  ('A1H703P9ALYVM6', 'B003VXFK44', 3.0),
#  ('A324A43N1MU8PY', 'B000H0ZJHW', 5.0),
#  ('A3BFXN08J3UCGL', 'B003CK0WLM', 5.0),
#  ('A1XQMQMF07QZQS', 'B0012C7VLG', 5.0),
#  ('A35R32TA60XD57', 'B003TC7WN4', 5.0),
#  ('A2GOTW3U8IIR7J', 'B000CQIDK6', 5.0),
#  ('AKOYMM5TTRIHQ', 'B000NMHYH2', 5.0),
#  ('A10G4BPT5MGBHY', 'B001OCBT3U', 4.0),
#  ('A1IKOG44PHFNYS', 'B00826I0II', 5.0),
#  ('A1QDB0LN3QX208', 'B002VZUW0A', 5.0),
#  ('A7YMD8MSOBO1I', 'B0036FB6FY', 5.0),
#  ('ANYKJWXT2W0IA', 'B00020HHAO', 5.0),
#  ('A1EE6LQS3OPY6R', 'B004FEN3GA', 3.0),
#  ('A1P2XYD265YE21', 'B004JRKEH4', 5.0),
#  ('A1LID3YS6I9O4F', 'B007NIARUA', 5.0),
#  ('A2M687HYOW9JFW', 'B000SP1CWW', 1.0),
#  ('ADL6LIYX03AQG', 'B000WFPH5G', 5.0),
#  ('ASC2DYLMA6N0C', 'B002G0CA6O', 4.0),
#  ('A2H1W8V6R9TJ9E', 'B006J4MAIQ', 5.0),
#  ('A2V1J3JT5OOZFO', 'B004UC7CMS', 5.0),
#  ('AJSQODVTPYBKP', 'B000WFKI82', 1.0),
#  ('A2CELHIBGYUDW5', 'B000E4AKQ6', 5.0),
#  ('ABUXAESDNAY17', 'B006N3I84I', 5.0),
#  ('A2ZVYE2WCSBUNP', 'B005CUU25G', 4.0),
#  ('AKMEY1BSHSDG7', 'B001EO5U3I', 5.0),
#  ('A3DADP1572NER3', 'B004UA52F4', 4.0),
#  ('A2PTFW5G285RHT', 'B001EQ4P2I', 5.0),
#  ('A1A8GHRWHEKEZJ', 'B0012TYZ4K', 4.0),
#  ('AI5SG3N6F0RMN', 'B006ABD1SG', 5.0),
#  ('A2QDTQVEVVJA5', 'B000Z3IQ0S', 5.0),
#  ('A12O5SEIF162P8', 'B007POT6RM', 5.0),
#  ('A2X9NU2VE0S01P', 'B002MMVPHQ', 5.0),
#  ('A29P51TN9KKMU9', 'B0092VQC3W', 5.0),
#  ('AMQ1MEG334SAP', 'B0051ZCSB8', 1.0),
#  ('A3FM0G6Z0JO7NT', 'B008JKU2CO', 5.0),
#  ('A3GQ26DZIIKOD', 'B003YK8YL0', 5.0),
#  ('A1KH5JOTGUPJD', 'B001181NBA', 5.0),
#  ('AJMY77NAPOLQ1', 'B001SIY5NQ', 4.0),
#  ('A2754OLX4JI486', 'B004HONIMC', 5.0),
#  ('A24PGDMY8R6MTF', 'B005HB4HGU', 4.0),
#  ('ANKQGTXHREOI5', 'B001BCXTGS', 3.0),
#  ('A21S0K5PU4YO9L', 'B007FK3JS8', 5.0),
#  ('A1UMSB7LAW0RIR', 'B003WEW9MS', 5.0),
#  ('A2OBDNQ5ZYU1L8', 'B0029NVJNI', 5.0),
#  ('A2IMLOJ2Z2QEU2', 'B0090X8IPM', 3.0),
#  ('A3DH53FPYSP9E', 'B002LANN56', 2.0),
#  ('A2FRFAQCWZJT3Q', 'B00427ZLOW', 3.0),
#  ('ADWL6PX6QM3ZJ', 'B005MWAPHE', 3.0),
#  ('A23W8MR1H3UHOZ', 'B001949REG', 1.0),
#  ('A1YN6Q7NN5IF0U', 'B004HYH8PK', 5.0),
#  ('A1R0Z1BJGWRH8E', 'B0032CB15Q', 1.0),
#  ('AQEQS5LG6W42M', 'B001PILVGI', 5.0),
#  ('AF1WN7WJRQ1DX', 'B0013KYXAO', 5.0),
#  ('A1N5FSCYN4796F', 'B001LNTY70', 3.0),
#  ('A1P2XYD265YE21', 'B005LIDZ26', 5.0),
#  ('A1Z4LX3Q1YMF84', 'B0012KH0M8', 5.0),
#  ('A18V01A7A12S24', 'B000EVQ2Q6', 5.0),
#  ('A4VMQ6ZTSXSSL', 'B004772OWE', 5.0),
#  ('A3DZFEICHK5LF2', 'B002NHYQAS', 4.0),
#  ('A3MDETK0D5UAIN', 'B0041NYV8E', 1.0),
#  ('A2SB8DPH72UOM7', 'B000VICB76', 2.0),
#  ('ADEZOPMPKK146', 'B008O3G25W', 5.0),
#  ('A3R9H6OKZHHRJD', 'B007RTR8UC', 4.0),
#  ('A36MZGJVT077WL', 'B006N3I7JO', 5.0),
#  ...]

# %%
# Estimate ratings for all products for the specified user
user_id = 'A383XURHVF8ON6'  # Replace with the actual UserId
product_ids = df_new['ProductId'].unique()  # Get all ProductIds
predictions = []

for product_id in product_ids:
    predicted_rating = svd.predict(user_id, product_id).est
    predictions.append((product_id, predicted_rating))

# Convert the predictions to a DataFrame
predictions_df = pd.DataFrame(predictions, columns=['ProductId', 'PredictedRating'])

# Get the top 10 products
top_10_products = predictions_df.sort_values(by='PredictedRating', ascending=False).head(20)

print(top_10_products)
# Out:
#         ProductId  PredictedRating
# 22694  B00488N8KY              5.0
# 2599   B001GVIUXQ              5.0
# 6213   B000EQYSLC              5.0
# 6214   B000SQMJE6              5.0
# 1344   B00434J154              5.0
# 13235  B000FD9314              5.0
# 11831  B0046GSTUM              5.0
# 23614  B001VPCDFS              5.0
# 6232   B0002CRZRW              5.0
# 9066   B000EA3M92              5.0
# 6239   B001ET5Y4I              5.0
# 6240   B000RJU8VU              5.0
# 1321   B000FKAYO2              5.0
# 25366  B004JM3LN8              5.0
# 6245   B001EO5ZCY              5.0
# 11816  B000F6SNQM              5.0
# 25379  B001OKGBAS              5.0
# 4183   B005DQCP9A              5.0
# 21304  B001EPQVUI              5.0
# 14396  B002ZBE67K              5.0

# %% [markdown]
# # **Using SVD & KNN_means in Ensamble Learning:**

# %%
# Instantiate the SVD model
svd_model = SVD(random_state=0, lr_all=0.1)

# Train the SVD model on the training set
svd_model.fit(trainset)

# Define and train KNNWithMeans model for user-based collaborative filtering
sim_options_user_knn = {
    'name': 'cosine',  # Use Pearson correlation for similarity
    'user_based': True  # This is user-user collaborative filtering
}

knn_user_model = KNNWithMeans(k=30, sim_options=sim_options_user_knn)
knn_user_model.fit(trainset)

# Define and train KNNWithMeans model for item-item collaborative filtering
sim_options_item_knn = {
    'name': 'pearson',  # Use Pearson correlation for similarity
    'user_based': False  # This is item-item collaborative filtering
}

knn_item_model = KNNWithMeans(k=10 ,sim_options=sim_options_item_knn)
knn_item_model.fit(trainset)

# Generate predictions
knn_user_predictions = knn_user_model.test(testset)
knn_item_predictions = knn_item_model.test(testset)
svd_predictions = svd_model.test(testset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
# # Create a test set from the training data to check the overfitting
# trainset_test = []

# for uid in trainset.all_users():
#     # Get the list of (item_id, rating) pairs for the user
#     user_ratings = trainset.ur[uid]  # This is a list of (item_id, rating) tuples
#     for iid, rating in user_ratings:
#         trainset_test.append((uid, iid, rating))
        
# # Generate predictions for the training set
# knn_user_predictions = knn_user_model.test(trainset_test)
# knn_item_predictions = knn_item_model.test(trainset_test)
# svd_predictions = svd_model.test(trainset_test)

# %%
len(testset)
print(testset)
# Out:
# [('ARWRBORADGA3G', 'B005K4Q1VI', 5.0), ('A35LT14WG5BX0T', 'B004OVATO8', 4.0), ('A318D41ZQ9OPNA', 'B001E18K8S', 3.0), ('AX1Z5RQ1LWMM2', 'B000OIT8T2', 5.0), ('A26NFIQ7KWI8Y7', 'B007OXJLM4', 4.0), ('A3F2VVIQIY6U64', 'B005BPVB84', 4.0), ('A9GQR7CMQERSS', 'B00141SO7A', 1.0), ('A15JB2HEZ6RKGW', 'B006MONQMC', 5.0), ('A2WYP6MZRK4G4A', 'B0029NIFXK', 5.0), ('A19ZK2D5664XKL', 'B000EQYQBO', 5.0), ('AWLK6NSSV0YNA', 'B004728MI4', 5.0), ('AS0SPE5TEM74Z', 'B004JLGDJI', 5.0), ('AZA55FJD7CCZN', 'B005VOONKI', 4.0), ('A3ACCH1UM0OKVU', 'B000WVYB8Y', 5.0), ('ACFPHOYVB71V4', 'B000G6MBUA', 5.0), ('ASPZBFGF4AS8H', 'B000MIDRNW', 5.0), ('A3FG0FQHNV2UP2', 'B007RTR8UM', 2.0), ('AI8EMB0HUC6Z5', 'B004BKLHOS', 5.0), ('A1MLQY4WBCWD31', 'B001SIRU42', 3.0), ('ADS99W8WMEXZ2', 'B005VOOL00', 4.0), ('A20J0NBT6FWXXM', 'B0041CIR62', 5.0), ('A37AO20OXS51QA', 'B000T3KTJA', 2.0), ('AUOA7P6T8JXSE', 'B0012BUR8Q', 5.0), ('AO09RWV40IX78', 'B000AY9U20', 5.0), ('A39ZG9XWPS3JU7', 'B005HB4HHO', 5.0), ('A15LK8DSFQZZ52', 'B004YV80OE', 3.0), ('A8PZHR49KMCRP', 'B002HFWNKG', 5.0), ('A3NCTCNAUYCH6H', 'B001EO5T52', 4.0), ('AYOMAHLWRQHUG', 'B001EO6BFE', 5.0), ('A9LWNO452P7UU', 'B000CONM86', 5.0), ('A2VH0UT5EQFB6P', 'B002LANN56', 4.0), ('A70T8C7VM2ZUW', 'B00073JVFU', 5.0), ('A1UMSB7LAW0RIR', 'B002T0NWKE', 5.0), ('A1F7SX3GNVBNE3', 'B005VTXQKG', 2.0), ('ABDBADU0RLIYN', 'B004IJHY4Y', 1.0), ('A3MUSWDCTZINQZ', 'B005VOOQHS', 5.0), ('A3882RXW8MO4J4', 'B0061IUIDY', 4.0), ('A2F2MZW8EOGH5J', 'B001TM2A24', 5.0), ('A1COSZMOI965TQ', 'B000VTTAMY', 1.0), ('A2HJPG1L877M73', 'B003CK0XC0', 5.0), ('A3JZJQHY3159IQ', 'B003VIWN1W', 4.0), ('A2MUGFV2TDQ47K', 'B0025UNVA4', 5.0), ('AL63HUU233ID2', 'B001SITXH4', 1.0), ('A26M5O53PHZTKN', 'B000JSLYSU', 5.0), ('A19XBW5WUDH1Z', 'B002ZJ3C18', 1.0), ('A7EK88GF8N40F', 'B004E4EBMG', 3.0), ('A1QR76SYGTXJN5', 'B008RWUHA6', 4.0), ('APPJNVNF4BFLB', 'B000UJW0W2', 2.0), ('AL7R5LO0AUGKQ', 'B000LKV7QA', 5.0), ('A5CG559ETQAWN', 'B000EVKHQM', 5.0), ('A18IZ3RTL9SD4V', 'B001RVFERK', 4.0), ('A2FS9CYCWC6HLW', 'B0014DUG0Q', 4.0), ('A37MH7ICH80QOX', 'B002RBOCZE', 4.0), ('A4E39G95DZXBC', 'B001SIRU42', 3.0), ('A1G34E8KZ8VQJO', 'B000LKXQ6O', 5.0), ('A3I7J622UUG6LB', 'B000EGZ2L2', 5.0), ('A385E4RHJS3T57', 'B0034EDM2W', 3.0), ('A1YUL9PCJR3JTY', 'B000JVCE5Y', 3.0), ('AYGIIQGSHKZNI', 'B000YZTAS4', 5.0), ('A1TNKFJBUL0ZAV', 'B000WFM9QQ', 5.0), ('A31MZR41SM9JU5', 'B002DHTWNO', 1.0), ('A1IZJVLNMFACS6', 'B007RTR8T8', 4.0), ('A2JMKYNXTG6MVN', 'B000EVG8J2', 5.0), ('A21U4DR8M6I9QN', 'B000WN47JU', 5.0), ('AENJBZSAD6ARY', 'B000E1FY3I', 5.0), ('A3CIVGG3HNS1GM', 'B001LG940E', 5.0), ('AWLK6NSSV0YNA', 'B000HGC988', 5.0), ('A376OJHLE6SU9Q', 'B002IEZJMA', 2.0), ('A1V2KJE03N4AE1', 'B000F4990I', 4.0), ('A2O421DTA8J0RW', 'B001AYDDCC', 4.0), ('A1QLPXFD05AMOU', 'B002YLG6I8', 5.0), ('A20A9P8EJ5BREG', 'B008EG5ADY', 4.0), ('ADPCK648WY0LZ', 'B000FVDWU4', 1.0), ('A2WLS1TTUUGJYU', 'B001ELL260', 5.0), ('A2EDWI5EGP4V9N', '7310172101', 4.0), ('A1SZTVG2IXWY2R', 'B000FPKX3O', 4.0), ('A2O421DTA8J0RW', 'B006BXUYN8', 5.0), ('A3L9ZT7SRJYLVH', 'B000SV5DKS', 5.0), ('A2IBUE2WR08IBH', 'B000OH57ZW', 5.0), ('A1LTDEUQUFK1WC', 'B007PA33QG', 3.0), ('A6VFX3VLU7NO6', 'B0087GG8OG', 5.0), ('A1421EDED1JI4I', 'B00166D8TW', 5.0), ('A27DYAY3FUWIZ8', 'B000FFQ1ZI', 5.0), ('A33PVCHCQ2BTN0', 'B00503DP0O', 5.0), ('A3LGT6UZL99IW1', 'B004YGQPAK', 4.0), ('A3D6OI36USYOU1', 'B00023323W', 5.0), ('A3UDKADSH2NSZU', 'B0019QT66I', 5.0), ('A33U8304RD0F6B', 'B0038C6X8A', 5.0), ('A19SXBQWY5Y4YW', 'B0030VJ8PE', 5.0), ('A2NML53YCHS80S', 'B005QRPHPU', 5.0), ('A370FTMPRF0AIK', 'B000Q7535Y', 5.0), ('A3W1ZA5JQVT33G', 'B000EDGBA6', 5.0), ('ARK11CB6Q8LQN', 'B00438XVGU', 5.0), ('A3MDETK0D5UAIN', 'B007RTR9DS', 2.0), ('ACG6O0II5IZE1', 'B001EO5QPA', 5.0), ('ANR7N0TPK3RB9', 'B001D0DMME', 5.0), ('A3N4CUW4UYC9I3', 'B0090X8IPM', 4.0), ('A2W3ABLWMJ84NS', 'B000LKVL16', 1.0), ('AIEEK7AHXKZCC', 'B000NMJWZO', 5.0), ('A2SSV6KM3W1VFD', 'B001BCVY9W', 5.0), ('A3JLECMNWC4LDY', 'B000CQID6U', 1.0), ('A21SL94J53BDS9', 'B006MONQMC', 3.0), ('A1BTHZO04GVCS6', 'B001BM8SS2', 5.0), ('A3QZ6JT0R1OWE ...

# %%
# Define weights for SVD and KNN
weight_svd = 0.7  # Weight for SVD predictions
weight_knn_user = 0.15  # Weight for user-based KNN predictions
weight_knn_item = 0.15  # Weight for item-based KNN predictions

# Combine predictions using weighted averaging
combined_predictions = []
for knn_user_pred, knn_item_pred, svd_pred in zip(knn_user_predictions, knn_item_predictions, svd_predictions):
    # Calculate the weighted average of the predicted ratings
    weighted_avg_rating = (weight_knn_user * knn_user_pred.est + 
                           weight_knn_item * knn_item_pred.est + 
                           weight_svd * svd_pred.est) / (weight_knn_user + weight_knn_item + weight_svd)
    
    # Create a new Prediction object with the weighted average rating
    combined_pred = knn_user_pred.__class__(uid=knn_user_pred.uid, 
                                             iid=knn_user_pred.iid, 
                                             est=weighted_avg_rating, 
                                             r_ui=knn_user_pred.r_ui,  # Actual rating
                                             details=knn_user_pred.details)  # Include details

    combined_predictions.append(combined_pred)

# %%
# Evaluate the combined predictions
rmse = accuracy.rmse(combined_predictions)
mae = accuracy.mae(combined_predictions)
# Out:
# RMSE: 0.7962
# MAE:  0.4914

# %%
# # Evaluate the combined predictions for trainset_test
# rmse = accuracy.rmse(combined_predictions)
# mae = accuracy.mae(combined_predictions)

# %%
'''''
For our recommendation system we will use 5 of the top rated products of the user (The highest score), and 
5 of the top unrated products predicted from the model
'''''
def recommendations(test_user_id):
    # Assuming df_new contains the actual ratings
    actual_ratings = df_new.copy()
    actual_ratings_list = []
    # Loop through the top 10 recommended products to get actual ratings
    for _, row in top_10_products.iterrows():
        product_id = row['ProductId']
        actual_rating = actual_ratings.loc[(actual_ratings['UserId'] == test_user_id) & 
                                            (actual_ratings['ProductId'] == product_id), 'Score']
        
        if not actual_rating.empty:
            actual_ratings_list.append(actual_rating.values[0])  # Append the actual rating
         
    # Get the actual ratings for the specific user
    user_actual_ratings = actual_ratings[actual_ratings['UserId'] == test_user_id]
    # Get the top 5 actual products based on Score
    top_actual_products = user_actual_ratings.sort_values(by='Score', ascending=False).head(5)
    
    
    
    
    # Now start deal with unrated products
    # Get all items the user has rated and a list of all items in the dataset
    rated_items = df_new[df_new['UserId'] == test_user_id]['ProductId'].unique()
    all_items = df_new['ProductId'].unique()
    
    #Filter out rated items to get unrated items
    unrated_items = [item for item in all_items if item not in rated_items]
    
    #Initialize lists to store predictions for unrated items for the user
    knn_user_predictions = []
    knn_item_predictions = []
    svd_user_predictions = []
    
    # Predict ratings for unrated items using KNN and SVD models
    for item_id in unrated_items:
        # Predict using user-based KNN
        knn_user_pred = knn_user_model.predict(test_user_id, item_id)
        knn_user_predictions.append(knn_user_pred)
        
        # Predict using item-based KNN
        knn_item_pred = knn_item_model.predict(test_user_id, item_id)
        knn_item_predictions.append(knn_item_pred)
        
        # Predict using SVD
        svd_pred = svd_model.predict(test_user_id, item_id)
        svd_user_predictions.append(svd_pred)
    
    #Combine predictions using weighted averaging
    combined_user_predictions = []
    
    for (knn_user_pred, knn_item_pred, svd_pred) in zip(knn_user_predictions, knn_item_predictions, svd_user_predictions):
        # Calculate the weighted average of the predicted ratings
        weighted_avg_rating = (weight_knn_user * knn_user_pred.est + 
                               weight_knn_item * knn_item_pred.est + 
                               weight_svd * svd_pred.est) / (weight_knn_user + weight_knn_item + weight_svd)
        
        # Create a new Prediction object with the weighted average rating
        combined_pred = knn_user_pred.__class__(uid=knn_user_pred.uid, 
                                                 iid=knn_user_pred.iid, 
                                                 est=weighted_avg_rating,
                                                 r_ui=None,  # No actual rating (since it's unrated)
                                                 details=knn_user_pred.details)  # Include details
    
        combined_user_predictions.append(combined_pred)
    
    #Convert combined predictions to a DataFrame for easier sorting
    combined_df = pd.DataFrame([(pred.iid, pred.est) for pred in combined_user_predictions], columns=['Item ID', 'Combined Prediction'])

    #Get the top 5 unrated products based on the combined ratings
    top_5_unrated_products = combined_df.sort_values(by='Combined Prediction', ascending=False).head(5)
    
    
    # Get the Product IDs of the top unrated products
    top_unrated_product_ids = top_5_unrated_products['Item ID'].tolist()
    # Get the Product IDs of the top actual products
    top_actual_product_ids = top_actual_products['ProductId'].tolist()
    # Combine the two lists of Product IDs
    final_recommendations = top_unrated_product_ids + top_actual_product_ids

    return final_recommendations, top_actual_products, top_5_unrated_products

# %%
'''''
Here we will get the hot 3 products that: 1-have the highest score and number of ratings. 
2-most related to the user using item-item collaborative filtering.
'''''
def trendy_products(test_user_id):
    
    # Calculate the number of ratings and average rating for each product
    product_ratings = df_new.groupby('ProductId')['Score'].agg(NumberOfRatings='count', AverageRating='mean').reset_index()
    
    # Calculate a popularity score by multiplying the number of ratings by the average rating
    product_ratings['PopularityScore'] = product_ratings['NumberOfRatings'] * product_ratings['AverageRating']
    
    # Sort the products by popularity score in descending order
    hot_products = product_ratings.sort_values(by='PopularityScore', ascending=False)
    
    # Exclude products already rated by the user
    rated_product_ids = df_new[df_new['UserId'] == test_user_id]['ProductId'].unique()
    hot_products = hot_products[~hot_products['ProductId'].isin(rated_product_ids)]
    
    # Generate predictions for unrated items using the item-item collaborative filtering model
    unrated_products = hot_products['ProductId'].unique()
    item_item_predictions = []
    for product_id in unrated_products:
        prediction = knn_item_model.predict(test_user_id, product_id)  # Get prediction from item-item model
        item_item_predictions.append((product_id, prediction.est))  # Store product ID and predicted rating
    
    # Convert predictions to DataFrame
    item_item_df = pd.DataFrame(item_item_predictions, columns=['ProductId', 'PredictedRating'])

    # Merge item-item predictions with hot products(Products shared between hot products and item_item_df)
    combined_hot_products = hot_products.merge(item_item_df, on='ProductId')
    
    # Sort by both popularity score and predicted rating
    recommended_products = combined_hot_products.sort_values(by=['PopularityScore', 'PredictedRating'], ascending=False)
    
    # Select the top 3 products
    top_3_recommended_products = recommended_products.head(3)
        
    #Save the trendy products ids in trendy_item_ids
    trendy_item_ids = top_3_recommended_products['ProductId'].tolist()
    return trendy_item_ids, top_3_recommended_products

# %%
user_id = 'A383XURHVF8ON6'

recommendations10, top_actual_products, top_5_unrated_products = recommendations(user_id)
trendy_item_ids, top_3_recommended_products = trendy_products(user_id)

# Print the final recommendations
print(f"\nRecommendations for user {user_id}:")

# First, display the trendy (hot) products
print("\nHot Products (Trending):")
for product in trendy_item_ids: 
    print(f"- Product ID: {product}")

# Then, display the 10 recommended products
print("\nThe 10 Recommended Products:")
for product in recommendations10:  
    print(f"- Product ID: {product}")
# Out:
# Recommendations for user A383XURHVF8ON6:
#
# Hot Products (Trending):
# - Product ID: B002IEVJRY
# - Product ID: B002IEZJMA
# - Product ID: B0026KPDG8
#
# The 10 Recommended Products:
# - Product ID: B00135XQCK
# - Product ID: B001FSK3PI
# - Product ID: B0009JOX2S
# - Product ID: B002T0EX7U
# - Product ID: B000E158ES
# - Product ID: B0002Z9BF8
# - Product ID: B001DY6TWU
# - Product ID: B000EMOD3O
# - Product ID: B000VVT9IM
# - Product ID: B001HN5Z4K

# %%
# Display the actual top products for the specific user
print(f"\nTop 5 Actual Products for user {user_id}:")
for index, row in top_actual_products.iterrows():
    print(f"Item ID: {row['ProductId']}, Actual Rating: {row['Score']}")

#Display the top 5 unrated product predictions for the specific user
print(f"\nTop 5 Unrated Product Predictions for user {user_id}:")
for index, row in top_5_unrated_products.iterrows():
    print(f"Item ID: {row['Item ID']}, Combined Prediction: {row['Combined Prediction']}")
# Out:
# Top 5 Actual Products for user A383XURHVF8ON6:
# Item ID: B0002Z9BF8, Actual Rating: 5
# Item ID: B001DY6TWU, Actual Rating: 5
# Item ID: B000EMOD3O, Actual Rating: 5
# Item ID: B000VVT9IM, Actual Rating: 5
# Item ID: B001HN5Z4K, Actual Rating: 5
#
# Top 5 Unrated Product Predictions for user A383XURHVF8ON6:
# Item ID: B000EDGBDI, Combined Prediction: 5.0
# Item ID: B001J8H1E0, Combined Prediction: 5.0
# Item ID: B000EDG3UE, Combined Prediction: 5.0
# Item ID: B0029NTQ1K, Combined Prediction: 5.0
# Item ID: B0083QJU5O, Combined Prediction: 5.0

# %%
# Display the recommended hot products
print("Top 3 Recommended Hot Products for user:", user_id)
for index, row in top_3_recommended_products.iterrows():
    print(f"Item ID: {row['ProductId']}, "
          f"Popularity Score: {row['PopularityScore']}, "
          f"Predicted Rating: {row['PredictedRating']}, "
          f"Number of Ratings: {row['NumberOfRatings']}, "
          f"Average Rating: {row['AverageRating']}")
# Out:
# Top 3 Recommended Hot Products for user: A383XURHVF8ON6
# Item ID: B002IEVJRY, Popularity Score: 1433.0, Predicted Rating: 4.2342337655058415, Number of Ratings: 373, Average Rating: 3.841823056300268
# Item ID: B002IEZJMA, Popularity Score: 1379.0, Predicted Rating: 4.519109450255137, Number of Ratings: 390, Average Rating: 3.5358974358974358
# Item ID: B0026KPDG8, Popularity Score: 1299.0, Predicted Rating: 5.0, Number of Ratings: 304, Average Rating: 4.2730263157894735

# %% [markdown]
# # **MLOps**
# This part was run using kaggle

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /opt/conda/lib/python3.10/site-packages (2.17.0)
# Requirement already satisfied: mlflow-skinny==2.17.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.17.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.13.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.4)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.6)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.7.5)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.2.2)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.10/site-packages (from mlflow) (1.14.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow) (2.0.30)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/conda/lib/python3.10/site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: gunicorn<24 in /opt/conda/lib/python3.10/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (0.35.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.43)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (7.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (1.25.0)
# Requirement already satisfied: packaging<25 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (21.3)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (3.20.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from mlflow-skinny==2.17.0->mlflow) (0.5.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.18)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask<4->mlflow) (1.8.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.5)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: google-auth~=2.0 in /opt/conda/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.30.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.0->mlflow) (3.19.2)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (0.46b0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (2024.8.30)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.6.0)

# %%
import os
import mlflow
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
from surprise import KNNWithMeans

os.makedirs('/kaggle/working/mlrun', exist_ok=True)
mlflow.set_tracking_uri('/kaggle/working/mlrun')

experiment_name = "itemm"
mlflow.set_experiment(experiment_name)


with mlflow.start_run():
    reader = Reader(line_format='user item rating timestamp', sep='\t', rating_scale=(1, 5))
    data = Dataset.load_from_df(df_new[['UserId', 'ProductId', 'Score']], reader)
    sim_options = {"name": "cosine", "user_based": False}  
    k= 40
    item_based = KNNWithMeans(k=k, sim_options=sim_options)
    cv = cross_validate(item_based, data, cv=5, measures=['RMSE','MAE'], verbose=True)

    
    mlflow.log_param("model_type", "KNNWithMeans")
    mlflow.log_param("similarity", "cosine")
    mlflow.log_param("n_neighbors", k)

    mlflow.log_metric("RMSE", cv['test_rmse'].mean())
    mlflow.log_metric("MAE", cv['test_mae'].mean())

    mlflow.sklearn.log_model(item_based, "knn_model")
    
    mlflow.end_run()
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9015  0.9095  0.9064  0.9102  0.9169  0.9089  0.0051
# MAE (testset)     0.5393  0.5465  0.5430  0.5480  0.5463  0.5446  0.0031
# Fit time          28.04   28.48   26.53   29.30   42.65   31.00   5.89
# Test time         1.57    1.51    1.64    2.25    2.10    1.82    0.30
# 2024/10/20 21:01:30 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpt13gysj4/model/model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.2.2', 'cloudpickle==3.0.0']. Set logging level to DEBUG to see the full traceback.
# 2024/10/20 21:01:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
import mlflow
import pandas as pd

# Retrieve all runs
runs = mlflow.search_runs()

# Convert to DataFrame
df_runs = pd.DataFrame(runs)

# Select relevant columns
columns_of_interest = [ 'params.model_type', 'params.n_neighbors', 'params.similarity', 'metrics.RMSE', 'metrics.MAE']
df_filtered = df_runs[columns_of_interest]

# Rename columns for clarity
df_filtered.columns = [ 'Model Type', 'K', 'Similarity', 'RMSE', 'MAE']

# Sort by RMSE or MAE (choose one depending on your preference)
df_sorted = df_filtered.sort_values(by='RMSE')  # Change to 'MAE' to sort by MAE

# Reset index for a cleaner look
df_sorted.reset_index(drop=True, inplace=True)

# Display the organized DataFrame
print(df_sorted)
# Out:
#      Model Type   K Similarity      RMSE       MAE
# 0  KNNWithMeans  10    pearson  0.899115  0.505366
# 1  KNNWithMeans  40     cosine  0.908886  0.544615
# 2  KNNWithMeans  10     cosine  0.911373  0.542600
